# %%
#Importing all the neccesary libraries
import numpy as np 
import pandas as pd 
import csv

import os
print(os.listdir("input"))

import regex as re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import SnowballStemmer
# from wordcloud import WordCloud

# viz
import matplotlib.pyplot as plt
# %matplotlib inline
import sys

# for clustering
from scipy.cluster.hierarchy import ward, dendrogram, fcluster, single, complete, average, weighted
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import squareform
from sklearn.metrics import silhouette_score
# Out:
# ['.ipynb_checkpoints', 'Bug report.csv', 'JIRA-ALL.csv', 'JIRA-BUG.csv', 'mozilla_firefox']

# %%
data=pd.read_csv('Input/JIRA-BUG.csv')
data = data.reset_index()

# %%
cols_of_interest=["Summary", "Status","Description","Priority","Resolution", "Issue Type", "Bug Location"]
data=data[cols_of_interest]
print(data.shape)
data.head()
# Out:
# (651, 7)
#                                              Summary       Status  \
# 0  [Dev][Demo][Admin Portal][Edit Bundle items]: ...        To Do
# 1  [Dev][Admin Portal][Create New][Create From ex...  In Progress
# 2  Duplicate items while using Search items by ke...        To Do
# 3  [AP] Default language and default region of st...           QA
# 4  [Unity][SDK] Single draft store makes subscrip...        To Do
#
#                                          Description Priority Resolution  \
# 0  This issue occurs on *Add new bundle items.*\n...       P1        NaN
# 1  This issue occurs on Create new Role and Creat...       P1        NaN
# 2  While making script for cleanup, we found that...       P2        NaN
# 3  When we open Stores menu and look at the store...       P1        NaN
# 4  The restriction of single draft store makes su...       P1        NaN
#
#   Issue Type     Bug Location
# 0        Bug     Admin Portal
# 1        Bug     Admin Portal
# 2        Bug  Automation Test
# 3        Bug     Admin Portal
# 4        Bug              SDK

# %%
fig = plt.figure(figsize=(8,6))
data.groupby('Bug Location').Status.count().plot.bar(ylim=0)
plt.show()

# %%
data.Description = data.Description.fillna("0")
data.isnull().sum()
# Out:
# Summary          0
# Status           0
# Description      0
# Priority         0
# Resolution      97
# Issue Type       0
# Bug Location     0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Summary          0
# Status           0
# Description      0
# Priority         0
# Resolution      97
# Issue Type       0
# Bug Location     0
# dtype: int64

# %% [markdown]
# **Text data preprocessing steps**
#
# 1- Data Cleaning(either using regex or BeautifulSoup):
# a) Removing HTML characters.
# b) Removing punctuation.
# c) Decoding encoded data.
# d) Split attached words.
# e) Removing URLs.
# f) Apostrophe removal.
# g) Removing Expressions.
# h) Uppercase & Lowercase letters
# i) Numbers such as amounts and data.
#
# 2- Data Tokenization(using word_tokenize in nltk.tokenize)
# Segregation of text into individual words i.e tokens.
#
# 3- Stopword Removal(using stopwords in nltk.corpus)
# Discarding too common words or words which are not going to be helpful in our analysis.
#
# 4- Stemming(using WordNetLemmatizer in nltk.stem)
# Combining different variants of words into a single parent word that conveys same meaning.

# %%
stops = set(stopwords.words("english"))

# %%
data['Concat'] = data.Summary +" "+ data.Description+" "+data["Bug Location"]
data.to_csv("./Output/data_concat.csv")

# %%
def clean_Description(content):
#     content = table.Description
    #Converting text to lowercase characters
    content = content.apply(lambda x: x.lower())
    #Removing HTML tags
    content = content.apply(lambda x: re.sub(r'\<[^<>]*\>','',x))
    #Removing any character which does not match to letter,digit or underscore
    content = content.apply(lambda x: re.sub(r'^\W+|\W+$',' ',x))
    #Removing space,newline,tab
    content = content.apply(lambda x: re.sub(r'\s',' ',x))
    #Removing punctuation
    content = content.apply(lambda x: re.sub(r'[^a-zA-Z0-9]',' ',x))
    #Removing numeric
    content = content.apply(lambda x: re.sub(r'[0-9]','',x))
    #Tokenizing data
    content = content.apply(lambda x: word_tokenize(x))
    #Removing stopwords
    content = content.apply(lambda x: [i for i in x if i not in stops])
    type(content)
    return(content)

# %%
dataClean = pd.DataFrame()
data['Concat'] = clean_Description(data['Concat'])
dataClean['Concat'] = data['Concat']

# %%
dataClean.head()
# Out:
#                                               Concat
# 0  [dev, demo, portal, edit, bundle, items, add, ...
# 1  [dev, portal, create, new, create, existing, a...
# 2  [duplicate, items, using, search, items, keywo...
# 3  [ap, default, language, default, region, store...
# 4  [unity, sdk, single, draft, store, makes, subs...

# %% [markdown]
# ## Stemming

# %%
data.dtypes
# Out:
# Summary         object
# Status          object
# Description     object
# Priority        object
# Resolution      object
# Issue Type      object
# Bug Location    object
# Concat          object
# dtype: object

# %%
wordnet = WordNetLemmatizer()
dataClean.Concat = dataClean.Concat.apply(lambda x:[wordnet.lemmatize(i,pos='v') for i in x])

# %%
dataClean['Concat'] = dataClean['Concat'].astype(str)
dataClean['Concat'] = dataClean['Concat'].apply(lambda x: re.sub(r'\s',' ',x))
dataClean['Concat'] = dataClean['Concat'].apply(lambda x: re.sub(r'[^a-zA-Z0-9]',' ',x))
dataClean['Concat'] = dataClean['Concat'].apply(lambda x: re.sub(r'^\W+|\W+$',' ',x))

# %%
dataClean.head()
dataClean.to_csv("./Output/token_concat.csv")

# %%
from nltk.util import everygrams
def ngramconvert(df,n=2,col=""):
    for item in df.columns:
        df[col]=df[item].apply(lambda sentence: list(everygrams(sentence.split(), max_len=n)))
    return df

# %%
new_df = ngramconvert(dataClean,2,"nGram")
new_df.head()
# Out:
#                                               Concat  \
# 0   dev    demo    portal    edit    bundle    it...
# 1   dev    portal    create    new    create    e...
# 2   duplicate    items    use    search    items ...
# 3   ap    default    language    default    regio...
# 4   unity    sdk    single    draft    store    m...
#
#                                                nGram
# 0  [(dev,), (demo,), (portal,), (edit,), (bundle,...
# 1  [(dev,), (portal,), (create,), (new,), (create...
# 2  [(duplicate,), (items,), (use,), (search,), (i...
# 3  [(ap,), (default,), (language,), (default,), (...
# 4  [(unity,), (sdk,), (single,), (draft,), (store...

# %%
dataClean.head()
# Out:
#                                               Concat  \
# 0   dev    demo    portal    edit    bundle    it...
# 1   dev    portal    create    new    create    e...
# 2   duplicate    items    use    search    items ...
# 3   ap    default    language    default    regio...
# 4   unity    sdk    single    draft    store    m...
#
#                                                nGram
# 0  [(dev,), (demo,), (portal,), (edit,), (bundle,...
# 1  [(dev,), (portal,), (create,), (new,), (create...
# 2  [(duplicate,), (items,), (use,), (search,), (i...
# 3  [(ap,), (default,), (language,), (default,), (...
# 4  [(unity,), (sdk,), (single,), (draft,), (store...

# %%
# desc = ' '
# for x in data.Concat:
#     for y in x:
#         desc+=' '+y

# %%
# plt.figure(figsize=(8,10))
# wc = WordCloud(max_words=1000,random_state=1).generate(desc)
# plt.imshow(wc)
# plt.show()

# %%
Summary = dataClean.Concat.astype(str)
listOfSummary = dataClean.nGram

# %%
listOfSummary
# Out:
# 0      [(dev,), (demo,), (portal,), (edit,), (bundle,...
# 1      [(dev,), (portal,), (create,), (new,), (create...
# 2      [(duplicate,), (items,), (use,), (search,), (i...
# 3      [(ap,), (default,), (language,), (default,), (...
# 4      [(unity,), (sdk,), (single,), (draft,), (store...
#                              ...
# 646    [(stg,), (launcher,), (launcher,), (start,), (...
# 647    [(stg,), (launcher,), (set,), (revert,), (last...
# 648    [(stg,), (ap,), (portal,), (feature,), (conten...
# 649    [(stg,), (ap,), (option,), (update,), (client,...
# 650    [(backend,), (get,), (use,), (different,), (na...
# Name: nGram, Length: 651, dtype: object

# %% [markdown]
# # Hiearchical Clustering

# %% [markdown]
# ## Jaccard Coeffient

# %%
import itertools
def compute_jaccard(str1, str2):
    himpunan1 = set(str1)
    himpunan2 = set(str2)
    irisan = himpunan1.intersection(himpunan2)
    gabungan = himpunan1.union(himpunan2)
    jaccard = len(irisan)/float(len(gabungan))
    
    return jaccard

# %%
sim_df = pd.DataFrame()

for col_pair in itertools.combinations_with_replacement(listOfSummary,2):
    strOfCol = str(col_pair)
    
    u0 = col_pair[0]
    u1 = col_pair[1]
    sim_df.loc[str(col_pair[0]), str(col_pair[1])] = compute_jaccard(u0, u1)

# %%
np.savetxt("./Output/distance_matrix_before_fillna.csv", np.array(sim_df), delimiter=",")

# %%
sim_df = sim_df.fillna(0)

# %%
dist = np.array(sim_df)
print(dist)
# Out:
# [[1.         0.16239316 0.01360544 ... 0.02631579 0.03614458 0.01538462]
#  [0.         1.         0.02884615 ... 0.03636364 0.04       0.00645161]
#  [0.         0.         1.         ... 0.00793651 0.0141844  0.02424242]
#  ...
#  [0.         0.         0.         ... 1.         0.2195122  0.07317073]
#  [0.         0.         0.         ... 0.         1.         0.06666667]
#  [0.         0.         0.         ... 0.         0.         1.        ]]

# %%
# ndist = dist[:, ~np.isnan(dist).any(axis=0)]
# # print(ndist)

# %%
np.savetxt("./Output/distance_matrix.csv", dist, delimiter=",")

# %% [markdown]
# ## Agglomerative Hierarchical Clustering

# %%
linkage_matrix = ward(dist) # replace with complete, single, or other scipy.cluster.hierarchical algorithms

# %% [markdown]
# ## Visualization
#
# Dendrogram visualization. We visualize the titles of each paper next to the corresponding leaf to qualitatively evaluate the clustering.
#
# Changing the `color_threshold` kwarg in the call to `dendrogram()` will affect how the clusters are displayed by increasing or decreasing the
# minimum distance necessary for `dendrogram()` to color a cluster differently.

# %%
# sys.setrecursionlimit(10000)
# MAX_COPHENETIC_DIST = max(linkage_matrix[:,2]) * 0.39 # max distance between points to be considered together. can be tuned.
# MAX_TITLE_LEN = 200

# fig, ax = plt.subplots(figsize=(15, 80)) # set size
# ax = dendrogram(linkage_matrix, orientation="right", color_threshold=MAX_COPHENETIC_DIST, leaf_font_size=4, labels=Summary.apply(lambda x: x if len(x) < MAX_TITLE_LEN else x[:MAX_TITLE_LEN  - 3] + "...").tolist())

# plt.tick_params(axis= 'x', which='both',  bottom='off', top='off',labelbottom='off')

# plt.tight_layout() #show plot with tight layout
# plt.savefig('./Output/jaccard-coeff-ward.png', dpi=300)

# %% [markdown]
# # Analysis
#
# We now take the raw clusters achieved and use the silhouette score and elbow method to evaluate.

# %%
def silhouette_k(distance_matrix, linkage_matrix, max_k=20):
    scores = []
    for i in range(2, max_k+1):
        clusters = fcluster(linkage_matrix, i, criterion='maxclust')
        score = silhouette_score(distance_matrix, clusters, metric='precomputed')
        print("Silhouette score with {} clusters:".format(i), score)
        scores.append(score)
    plt.title("Silhouette score vs. number of clusters")
    plt.xlabel("# of clusters")
    plt.ylabel("Score (higher is better)")
    plt.plot(np.arange(2, max_k+1), scores)
    plt.show()
    return scores

# %%
np.fill_diagonal(dist, 0)
_ = silhouette_k(dist, linkage_matrix)
# Out:
# Silhouette score with 2 clusters: -0.8341354636897622
# Silhouette score with 3 clusters: -0.8785299098743564
# Silhouette score with 4 clusters: -0.8844543445637898
# Silhouette score with 5 clusters: -0.9651745411758134
# Silhouette score with 6 clusters: -0.9640696331822883
# Silhouette score with 7 clusters: -0.9652052366681454
# Silhouette score with 8 clusters: -0.9653445230820211
# Silhouette score with 9 clusters: -0.9641070854718737
# Silhouette score with 10 clusters: -0.9636779002802748
# Silhouette score with 11 clusters: -0.96245685800079
# Silhouette score with 12 clusters: -0.9644107274055057
# Silhouette score with 13 clusters: -0.965061205087306
# Silhouette score with 14 clusters: -0.9655374962370692
# Silhouette score with 15 clusters: -0.9659947181215984
# Silhouette score with 16 clusters: -0.9656287336579306
# Silhouette score with 17 clusters: -0.9656115938098929
# Silhouette score with 18 clusters: -0.9647122611302236
# Silhouette score with 19 clusters: -0.9631756452152497
# Silhouette score with 20 clusters: -0.9621958856244116

# %% [markdown]
#  # Hierarchical Clustering Using Jaccard Coefficient and IDF

# %%
def calc_DF(tfDict):
    count_DF = {}
    # Run through each document's tf dictionary and increment countDict's (term, doc) pair
    for document in tfDict:
        for term in document:
            if term in count_DF:
                count_DF[term] += 1
            else:
                count_DF[term] = 1
    return count_DF

DF = calc_DF(listOfSummary)
DF
# Out:
# {('dev',): 104,
#  ('demo',): 330,
#  ('portal',): 591,
#  ('edit',): 78,
#  ('bundle',): 26,
#  ('items',): 45,
#  ('add',): 161,
#  ('item',): 198,
#  ('type',): 71,
#  ('code',): 134,
#  ('season',): 2,
#  ('subscription',): 117,
#  ('return',): 59,
#  ('error',): 269,
#  ('response',): 39,
#  ('issue',): 193,
#  ('occur',): 126,
#  ('new',): 167,
#  ('already',): 69,
#  ('create',): 190,
#  ('draft',): 42,
#  ('store',): 182,
#  ('view',): 52,
#  ('please',): 110,
#  ('notice',): 134,
#  ('note',): 97,
#  ('also',): 55,
#  ('provide',): 7,
#  ('suitable',): 1,
#  ('message',): 156,
#  ('one',): 46,
#  ('show',): 139,
#  ('fail',): 125,
#  ('update',): 182,
#  ('try',): 113,
#  ('accountid',): 24,
#  ('see',): 101,
#  ('attachment',): 75,
#  ('detail',): 134,
#  ('dev', 'demo'): 15,
#  ('demo', 'portal'): 3,
#  ('portal', 'edit'): 1,
#  ('edit', 'bundle'): 1,
#  ('bundle', 'items'): 6,
#  ('items', 'add'): 1,
#  ('add', 'item'): 12,
#  ('item', 'type'): 10,
#  ('type', 'code'): 4,
#  ('code', 'season'): 2,
#  ('season', 'subscription'): 2,
#  ('subscription', 'return'): 2,
#  ('return', 'error'): 5,
#  ('error', 'response'): 8,
#  ('response', 'issue'): 1,
#  ('issue', 'occur'): 77,
#  ('occur', 'add'): 3,
#  ('add', 'new'): 12,
#  ('new', 'bundle'): 2,
#  ('items', 'already'): 1,
#  ('already', 'create'): 3,
#  ('create', 'item'): 3,
#  ('item', 'bundle'): 3,
#  ('bundle', 'type'): 2,
#  ('type', 'draft'): 1,
#  ('draft', 'store'): 41,
#  ('store', 'view'): 4,
#  ('view', 'bundle'): 2,
#  ('items', 'please'): 1,
#  ('please', 'notice'): 23,
#  ('notice', 'add'): 6,
#  ('response', 'note'): 1,
#  ('note', 'also'): 12,
#  ('also', 'please'): 1,
#  ('please', 'provide'): 1,
#  ('provide', 'suitable'): 1,
#  ('suitable', 'error'): 1,
#  ('error', 'message'): 61,
#  ('message', 'one'): 2,
#  ('one', 'show'): 1,
#  ('show', 'fail'): 9,
#  ('fail', 'update'): 3,
#  ('update', 'item'): 3,
#  ('item', 'try'): 2,
#  ('try', 'accountid'): 1,
#  ('accountid', 'please'): 2,
#  ('please', 'see'): 43,
#  ('see', 'attachment'): 47,
#  ('attachment', 'detail'): 61,
#  ('detail', 'portal'): 27,
#  ('exist',): 48,
#  ('able',): 73,
#  ('use',): 202,
#  ('role',): 55,
#  ('name',): 82,
#  ('clone',): 39,
#  ('dev', 'portal'): 1,
#  ('portal', 'create'): 1,
#  ('create', 'new'): 62,
#  ('new', 'create'): 3,
#  ('create', 'exist'): 4,
#  ('exist', 'able'): 1,
#  ('able', 'use'): 7,
#  ('use', 'role'): 3,
#  ('role', 'name'): 2,
#  ('name', 'already'): 2,
#  ('already', 'exist'): 4,
#  ('exist', 'issue'): 1,
#  ('occur', 'create'): 3,
#  ('new', 'role'): 7,
#  ('role', 'create'): 4,
#  ('exist', 'try'): 2,
#  ('try', 'create'): 10,
#  ('role', 'exist'): 1,
#  ('exist', 'clone'): 1,
#  ('clone', 'please'): 1,
#  ('notice', 'able'): 2,
#  ('exist', 'please'): 2,
#  ('duplicate',): 13,
#  ('search',): 92,
#  ('keyword',): 4,
#  ('endpoint',): 66,
#  ('pagination',): 13,
#  ('make',): 59,
#  ('script',): 24,
#  ('cleanup',): 1,
#  ('find',): 93,
#  ('data',): 125,
#  ('first',): 22,
#  ('page',): 223,
#  ('next',): 18,
#  ('compare',): 2,
#  ('without',): 33,
#  ('differences',): 1,
#  ('datas',): 1,
#  ('stg',): 32,
#  ('environment',): 20,
#  ('automation',): 25,
#  ('test',): 133,
#  ('duplicate', 'items'): 1,
#  ('items', 'use'): 3,
#  ('use', 'search'): 3,
#  ('search', 'items'): 5,
#  ('items', 'keyword'): 1,
#  ('keyword', 'endpoint'): 1,
#  ('endpoint', 'pagination'): 1,
#  ('pagination', 'make'): 1,
#  ('make', 'script'): 1,
#  ('script', 'cleanup'): 1,
#  ('cleanup', 'find'): 1,
#  ('find', 'search'): 5,
#  ('use', 'pagination'): 1,
#  ('pagination', 'duplicate'): 1,
#  ('duplicate', 'data'): 1,
#  ('data', 'first'): 1,
#  ('first', 'page'): 1,
#  ('page', 'next'): 1,
#  ('next', 'page'): 3,
#  ('page', 'compare'): 1,
#  ('compare', 'data'): 1,
#  ('data', 'pagination'): 1,
#  ('pagination', 'without'): 1,
#  ('without', 'pagination'): 1,
#  ('pagination', 'find'): 2,
#  ('find', 'differences'): 1,
#  ('differences', 'datas'): 1,
#  ('datas', 'exist'): 1,
#  ('exist', 'use'): 1,
#  ('items', 'pagination'): 1,
#  ('find', 'dev'): 1,
#  ('dev', 'stg'): 1,
#  ('stg', 'environment'): 1,
#  ('environment', 'automation'): 1,
#  ('automation', 'test'): 15,
#  ('ap',): 277,
#  ('default',): 35,
#  ('language',): 27,
#  ('region',): 15,
#  ('display',): 74,
#  ('properly',): 13,
#  ('open',): 55,
#  ('menu',): 57,
#  ('look',): 8,
#  ('list',): 61,
#  ('correctly',): 5,
#  ('id',): 123,
#  ('instead',): 40,
#  ('correct',): 17,
#  ('label',): 5,
#  ('example',): 21,
#  ('english',): 4,
#  ('us',): 18,
#  ('en',): 14,
#  ('ap', 'default'): 2,
#  ('default', 'language'): 6,
#  ('language', 'default'): 3,
#  ('default', 'region'): 3,
#  ('region', 'store'): 1,
#  ('store', 'display'): 2,
#  ('display', 'properly'): 3,
#  ('properly', 'open'): 1,
#  ('open', 'store'): 2,
#  ('store', 'menu'): 1,
#  ('menu', 'look'): 1,
#  ('look', 'store'): 1,
#  ('store', 'list'): 1,
#  ('list', 'notice'): 2,
#  ('notice', 'default'): 2,
#  ('region', 'display'): 1,
#  ('display', 'correctly'): 1,
#  ('correctly', 'show'): 1,
#  ('show', 'id'): 1,
#  ('id', 'instead'): 1,
#  ('instead', 'correct'): 1,
#  ('correct', 'label'): 2,
#  ('label', 'example'): 1,
#  ('example', 'correct'): 1,
#  ('label', 'default'): 1,
#  ('language', 'english'): 4,
#  ('english', 'us'): 2,
#  ('us', 'show'): 1,
#  ('show', 'en'): 1,
#  ('en', 'us'): 6,
#  ('us', 'instead'): 1,
#  ('instead', 'portal'): 1,
#  ('unity',): 37,
#  ('sdk',): 141,
#  ('single',): 11,
#  ('restriction',): 2,
#  ('rely',): 6,
#  ('platform',): 54,
#  ('obsolete',): 2,
#  ('feature',): 22,
#  ('multiple',): 12,
#  ('need',): 95,
#  ('rewrite',): 3,
#  ('unity', 'sdk'): 30,
#  ('sdk', 'single'): 2,
#  ('single', 'draft'): 7,
#  ('store', 'make'): 4,
#  ('make', 'subscription'): 4,
#  ('subscription', 'test'): 4,
#  ('test', 'fail'): 8,
#  ('fail', 'restriction'): 2,
#  ('restriction', 'single'): 2,
#  ('test', 'rely'): 2,
#  ('rely', 'platform'): 2,
#  ('platform', 'obsolete'): 2,
#  ('obsolete', 'feature'): 2,
#  ('feature', 'multiple'): 2,
#  ('multiple', 'draft'): 2,
#  ('store', 'fail'): 3,
#  ('fail', 'demo'): 2,
#  ('demo', 'test'): 3,
#  ('test', 'need'): 2,
#  ('need', 'rewrite'): 2,
#  ('rewrite', 'use'): 2,
#  ('use', 'single'): 2,
#  ('store', 'sdk'): 1,
#  ('unreal',): 2,
#  ('additional',): 4,
#  ('info',): 17,
#  ('https',): 523,
#  ('sdkbuild',): 9,
#  ('accelbyte',): 558,
#  ('net',): 185,
#  ('job',): 21,
#  ('justice',): 208,
#  ('continuous',): 1,
#  ('integration',): 14,
#  ('artifact',): 9,
#  ('save',): 32,
#  ('log',): 106,
#  ('essentials',): 1,
#  ('unreal', 'sdk'): 2,
#  ('store', 'additional'): 1,
#  ('additional', 'info'): 1,
#  ('info', 'https'): 1,
#  ('https', 'sdkbuild'): 9,
#  ('sdkbuild', 'accelbyte'): 9,
#  ('accelbyte', 'net'): 50,
#  ('net', 'job'): 9,
#  ('job', 'justice'): 9,
#  ('justice', 'unreal'): 1,
#  ('sdk', 'job'): 9,
#  ('job', 'continuous'): 1,
#  ('continuous', 'integration'): 1,
#  ('integration', 'artifact'): 1,
#  ('artifact', 'save'): 9,
#  ('save', 'log'): 9,
#  ('log', 'essentials'): 1,
#  ('essentials', 'log'): 1,
#  ('log', 'log'): 3,
#  ('log', 'sdk'): 3,
#  ('feedback',): 24,
#  ('pp',): 158,
#  ('currently',): 14,
#  ('hard',): 7,
#  ('specific',): 21,
#  ('game',): 285,
#  ('want',): 41,
#  ('work',): 29,
#  ('amount',): 34,
#  ('much',): 3,
#  ('pass',): 6,
#  ('certain',): 10,
#  ('become',): 12,
#  ('must',): 11,
#  ('player',): 215,
#  ('feedback', 'pp'): 1,
#  ('pp', 'add'): 3,
#  ('add', 'search'): 1,
#  ('search', 'feature'): 4,
#  ('feature', 'store'): 2,
#  ('store', 'currently'): 2,
#  ('currently', 'search'): 1,
#  ('store', 'pp'): 2,
#  ('pp', 'make'): 2,
#  ('make', 'hard'): 1,
#  ('hard', 'find'): 1,
#  ('find', 'specific'): 1,
#  ('specific', 'game'): 5,
#  ('game', 'want'): 1,
#  ('want', 'page'): 1,
#  ('page', 'work'): 2,
#  ('work', 'amount'): 1,
#  ('amount', 'game'): 1,
#  ('game', 'much'): 1,
#  ('much', 'pass'): 1,
#  ('pass', 'certain'): 1,
#  ('certain', 'amount'): 1,
#  ('amount', 'search'): 1,
#  ('feature', 'become'): 1,
#  ('become', 'must'): 1,
#  ('must', 'player'): 1,
#  ('player', 'portal'): 127,
#  ('launcher',): 405,
#  ('avatar',): 8,
#  ('get',): 228,
#  ('customize',): 2,
#  ('photo',): 2,
#  ('happen',): 105,
#  ('choose',): 29,
#  ('continue',): 8,
#  ('demo', 'launcher'): 30,
#  ('launcher', 'avatar'): 1,
#  ('avatar', 'get'): 1,
#  ('get', 'error'): 44,
#  ('error', 'customize'): 1,
#  ('customize', 'avatar'): 2,
#  ('avatar', 'without'): 1,
#  ('without', 'photo'): 2,
#  ('photo', 'issue'): 1,
#  ('issue', 'happen'): 50,
#  ('happen', 'customize'): 1,
#  ('avatar', 'launcher'): 2,
#  ('launcher', 'choose'): 2,
#  ('choose', 'continue'): 1,
#  ('continue', 'without'): 1,
#  ('photo', 'note'): 1,
#  ('note', 'issue'): 15,
#  ('happen', 'player'): 4,
#  ('portal', 'launcher'): 21,
#  ('backend',): 133,
#  ('namespace',): 257,
#  ('assign',): 8,
#  ('function',): 67,
#  ('head',): 3,
#  ('click',): 194,
#  ('roles',): 15,
#  ('png',): 58,
#  ('width',): 94,
#  ('height',): 93,
#  ('clone', 'portal'): 1,
#  ('portal', 'backend'): 1,
#  ('backend', 'game'): 1,
#  ('game', 'namespace'): 60,
#  ('namespace', 'assign'): 1,
#  ('assign', 'role'): 4,
#  ('role', 'function'): 1,
#  ('function', 'fail'): 1,
#  ('fail', 'occur'): 1,
#  ('occur', 'head'): 1,
#  ('head', 'game'): 1,
#  ('namespace', 'click'): 3,
#  ('click', 'roles'): 1,
#  ('roles', 'menu'): 1,
#  ('menu', 'try'): 1,
#  ('try', 'assign'): 1,
#  ('role', 'game'): 1,
#  ('namespace', 'fail'): 1,
#  ('fail', 'png'): 1,
#  ('png', 'width'): 42,
#  ('width', 'height'): 93,
#  ('height', 'png'): 2,
#  ('height', 'portal'): 28,
#  ('recharge',): 4,
#  ('wallet',): 19,
#  ('coin',): 23,
#  ('count',): 15,
#  ('refresh',): 31,
#  ('successfully',): 23,
#  ('purchase',): 89,
#  ('succeed',): 1,
#  ('either',): 2,
#  ('go',): 455,
#  ('profile',): 32,
#  ('change',): 154,
#  ('demo', 'pp'): 26,
#  ('pp', 'launcher'): 48,
#  ('launcher', 'recharge'): 2,
#  ('recharge', 'wallet'): 1,
#  ('wallet', 'coin'): 1,
#  ('coin', 'count'): 2,
#  ('count', 'refresh'): 2,
#  ('refresh', 'successfully'): 1,
#  ('successfully', 'purchase'): 1,
#  ('purchase', 'currently'): 1,
#  ('currently', 'coin'): 1,
#  ('refresh', 'purchase'): 1,
#  ('purchase', 'succeed'): 1,
#  ('succeed', 'player'): 1,
#  ('player', 'either'): 1,
#  ('either', 'refresh'): 1,
#  ('refresh', 'page'): 8,
#  ('page', 'go'): 5,
#  ('go', 'profile'): 6,
#  ('profile', 'see'): 1,
#  ('see', 'change'): 1,
#  ('change', 'coin'): 1,
#  ('coin', 'launcher'): 1,
#  ('stag',): 13,
#  ('group',): 38,
#  ('complete',): 34,
#  ('request',): 117,
#  ('appear',): 84,
#  ('toast',): 6,
#  ('method',): 27,
#  ('allow',): 24,
#  ('trigger',): 35,
#  ('stag', 'group'): 1,
#  ('group', 'error'): 1,
#  ('message', 'fail'): 4,
#  ('fail', 'complete'): 19,
#  ('complete', 'request'): 19,
#  ('request', 'appear'): 2,
#  ('appear', 'view'): 1,
#  ('view', 'group'): 1,
#  ('group', 'detail'): 1,
#  ('detail', 'issue'): 3,
#  ('happen', 'portal'): 8,
#  ('portal', 'want'): 6,
#  ('want', 'view'): 1,
#  ('view', 'detail'): 1,
#  ('detail', 'group'): 1,
#  ('group', 'go'): 1,
#  ('go', 'group'): 1,
#  ('group', 'list'): 3,
#  ('list', 'detail'): 2,
#  ('detail', 'click'): 2,
#  ('click', 'view'): 21,
#  ('view', 'one'): 4,
#  ('one', 'exist'): 1,
#  ('exist', 'group'): 1,
#  ('group', 'toast'): 1,
#  ('toast', 'fail'): 1,
#  ('request', 'error'): 2,
#  ('response', 'method'): 1,
#  ('method', 'allow'): 1,
#  ('allow', 'trigger'): 1,
#  ('trigger', 'portal'): 1,
#  ('reload',): 9,
#  ('charge',): 1,
#  ('active',): 46,
#  ('success',): 60,
#  ('payment',): 96,
#  ('via',): 12,
#  ('prime',): 30,
#  ('status',): 43,
#  ('myaccount',): 1,
#  ('remain',): 7,
#  ('init',): 3,
#  ('auto',): 9,
#  ('stag', 'pp'): 2,
#  ('launcher', 'subscription'): 5,
#  ('subscription', 'need'): 1,
#  ('need', 'reload'): 2,
#  ('reload', 'page'): 5,
#  ('page', 'make'): 2,
#  ('make', 'charge'): 1,
#  ('charge', 'subscription'): 1,
#  ('subscription', 'become'): 1,
#  ('become', 'active'): 3,
#  ('active', 'issue'): 1,
#  ('occur', 'player'): 6,
#  ('portal', 'player'): 10,
#  ('player', 'success'): 2,
#  ('success', 'make'): 3,
#  ('make', 'payment'): 3,
#  ('payment', 'subscription'): 3,
#  ('subscription', 'via'): 1,
#  ('via', 'menu'): 1,
#  ('menu', 'prime'): 1,
#  ('prime', 'subscription'): 4,
#  ('subscription', 'status'): 3,
#  ('status', 'myaccount'): 1,
#  ('myaccount', 'subscription'): 1,
#  ('subscription', 'remain'): 2,
#  ('remain', 'init'): 1,
#  ('init', 'auto'): 1,
#  ('auto', 'update'): 5,
#  ('update', 'become'): 2,
#  ('active', 'need'): 1,
#  ('page', 'log'): 2,
#  ('log', 'update'): 1,
#  ('active', 'launcher'): 2,
#  ('product',): 21,
#  ('key',): 60,
#  ('upload',): 24,
#  ('empty',): 23,
#  ('stag', 'product'): 1,
#  ('product', 'key'): 18,
#  ('key', 'able'): 1,
#  ('able', 'upload'): 2,
#  ('upload', 'empty'): 1,
#  ('empty', 'key'): 1,
#  ('key', 'id'): 1,
#  ('id', 'portal'): 6,
#  ('perform',): 6,
#  ('exact',): 4,
#  ('match',): 25,
#  ('email',): 290,
#  ('address',): 34,
#  ('attempt',): 5,
#  ('result',): 244,
#  ('eric',): 3,
#  ('expect',): 111,
#  ('server',): 78,
#  ('several',): 15,
#  ('register',): 25,
#  ('contain',): 14,
#  ('snyder',): 3,
#  ('account',): 264,
#  ('fuzzy',): 1,
#  ('ones',): 1,
#  ('username',): 25,
#  ('locate',): 2,
#  ('dev', 'search'): 1,
#  ('search', 'portal'): 1,
#  ('portal', 'perform'): 1,
#  ('perform', 'exact'): 1,
#  ('exact', 'match'): 3,
#  ('match', 'search'): 1,
#  ('search', 'email'): 2,
#  ('email', 'address'): 30,
#  ('address', 'attempt'): 1,
#  ('attempt', 'search'): 1,
#  ('search', 'via'): 1,
#  ('via', 'email'): 2,
#  ('address', 'portal'): 1,
#  ('portal', 'result'): 1,
#  ('result', 'return'): 2,
#  ('return', 'exact'): 1,
#  ('match', 'happen'): 1,
#  ('happen', 'demo'): 3,
#  ('demo', 'search'): 1,
#  ('search', 'eric'): 1,
#  ('eric', 'return'): 1,
#  ('return', 'result'): 1,
#  ('result', 'expect'): 6,
#  ('expect', 'dev'): 1,
#  ('dev', 'server'): 1,
#  ('server', 'several'): 1,
#  ('several', 'email'): 2,
#  ('email', 'register'): 1,
#  ('register', 'contain'): 1,
#  ('contain', 'eric'): 1,
#  ('eric', 'snyder'): 2,
#  ('snyder', 'account'): 1,
#  ('account', 'show'): 5,
#  ('show', 'fuzzy'): 1,
#  ('fuzzy', 'search'): 1,
#  ('search', 'ones'): 1,
#  ('ones', 'contain'): 1,
#  ('contain', 'snyder'): 1,
#  ('snyder', 'username'): 1,
#  ('username', 'eric'): 1,
#  ('snyder', 'accelbyte'): 1,
#  ('net', 'locate'): 1,
#  ('locate', 'via'): 1,
#  ('via', 'exact'): 1,
#  ('match', 'portal'): 1,
#  ('gdpr',): 52,
#  ('deletion',): 49,
#  ('still',): 83,
#  ('iam',): 301,
#  ('delete',): 65,
#  ('io',): 111,
#  ('privacy',): 9,
#  ('notification',): 89,
#  ('gdpr', 'successfully'): 1,
#  ('successfully', 'perform'): 1,
#  ('perform', 'deletion'): 1,
#  ('deletion', 'deletion'): 1,
#  ('deletion', 'status'): 2,
#  ('status', 'still'): 2,
#  ('still', 'fail'): 3,
#  ('fail', 'iam'): 2,
#  ('iam', 'delete'): 1,
#  ('delete', 'deletion'): 1,
#  ('status', 'https'): 1,
#  ('https', 'dev'): 16,
#  ('dev', 'accelbyte'): 16,
#  ('accelbyte', 'io'): 106,
#  ('io', 'privacy'): 2,
#  ('privacy', 'account'): 2,
#  ('account', 'deletion'): 21,
#  ('deletion', 'request'): 9,
#  ('request', 'https'): 11,
#  ('request', 'still'): 1,
#  ('fail', 'get'): 1,
#  ('get', 'fail'): 4,
#  ('fail', 'email'): 1,
#  ('email', 'notification'): 27,
#  ('notification', 'portal'): 2,
#  ('ugc',): 26,
#  ('internet',): 20,
#  ('connection',): 33,
#  ('content',): 41,
#  ('creator',): 2,
#  ('fill',): 45,
#  ('require',): 19,
#  ('field',): 76,
#  ('select',): 68,
#  ('button',): 134,
#  ('seem',): 15,
#  ('cause',): 24,
#  ('cdn',): 1,
#  ('activate',): 1,
#  ('access',): 92,
#  ('deny',): 3,
#  ('preview',): 1,
#  ('stag', 'ugc'): 1,
#  ('ugc', 'error'): 1,
#  ('message', 'internet'): 2,
#  ('internet', 'connection'): 14,
#  ('connection', 'appear'): 1,
#  ('appear', 'create'): 1,
#  ('new', 'content'): 2,
#  ('content', 'creator'): 2,
#  ('creator', 'issue'): 1,
#  ('want', 'create'): 7,
#  ('creator', 'ugc'): 1,
#  ('ugc', 'fill'): 1,
#  ('fill', 'require'): 3,
#  ('require', 'field'): 5,
#  ('field', 'select'): 1,
#  ('select', 'click'): 1,
#  ('click', 'add'): 19,
#  ('add', 'button'): 8,
#  ('button', 'error'): 1,
#  ('connection', 'trigger'): 1,
#  ('trigger', 'note'): 1,
#  ('happen', 'dev'): 6,
#  ('demo', 'environment'): 8,
#  ('environment', 'seem'): 1,
#  ('seem', 'issue'): 2,
#  ('issue', 'cause'): 3,
#  ('cause', 'cdn'): 1,
#  ('cdn', 'activate'): 1,
#  ('activate', 'stag'): 1,
#  ('stag', 'environment'): 1,
#  ('environment', 'get'): 4,
#  ('get', 'access'): 4,
#  ('access', 'deny'): 2,
#  ('deny', 'preview'): 1,
#  ('preview', 'upload'): 1,
#  ('upload', 'portal'): 1,
#  ('call',): 13,
#  ('revoke',): 29,
#  ('submit',): 3,
#  ('latest',): 13,
#  ('commit',): 1,
#  ('dependency',): 2,
#  ('github',): 86,
#  ('com',): 367,
#  ('parnurzeal',): 2,
#  ('gorequest',): 2,
#  ('v',): 82,
#  ('suspect',): 3,
#  ('root',): 9,
#  ('vpn',): 1,
#  ('http',): 81,
#  ('report',): 14,
#  ('service',): 354,
#  ('gatling',): 22,
#  ('index',): 11,
#  ('html',): 12,
#  ('gdpr', 'fail'): 2,
#  ('fail', 'call'): 2,
#  ('call', 'iam'): 3,
#  ('iam', 'revoke'): 1,
#  ('revoke', 'endpoint'): 1,
#  ('endpoint', 'submit'): 1,
#  ('submit', 'deletion'): 1,
#  ('deletion', 'find'): 1,
#  ('find', 'latest'): 1,
#  ('latest', 'commit'): 1,
#  ('commit', 'dependency'): 1,
#  ('dependency', 'change'): 1,
#  ('change', 'github'): 1,
#  ('github', 'com'): 86,
#  ('com', 'parnurzeal'): 2,
#  ('parnurzeal', 'gorequest'): 2,
#  ('gorequest', 'v'): 2,
#  ('v', 'github'): 1,
#  ('v', 'suspect'): 1,
#  ('suspect', 'root'): 1,
#  ('root', 'cause'): 9,
#  ('cause', 'make'): 1,
#  ('make', 'gdpr'): 1,
#  ('iam', 'issue'): 1,
#  ('issue', 'find'): 1,
#  ('find', 'automation'): 1,
#  ('test', 'use'): 8,
#  ('use', 'vpn'): 1,
#  ('vpn', 'access'): 1,
#  ('access', 'http'): 2,
#  ('http', 'report'): 9,
#  ('report', 'accelbyte'): 9,
#  ('io', 'automation'): 9,
#  ('automation', 'dev'): 6,
#  ('dev', 'justice'): 9,
#  ('justice', 'gdpr'): 4,
#  ('gdpr', 'service'): 9,
#  ('service', 'gatling'): 9,
#  ('gatling', 'test'): 10,
#  ('test', 'index'): 9,
#  ('index', 'html'): 9,
#  ('html', 'http'): 2,
#  ('html', 'portal'): 1,
#  ('publish',): 74,
#  ('automatically',): 19,
#  ('action',): 30,
#  ('option',): 17,
#  ('condition',): 7,
#  ('modal',): 20,
#  ('pop',): 27,
#  ('workaround',): 21,
#  ('section',): 43,
#  ('stag', 'store'): 1,
#  ('store', 'publish'): 4,
#  ('publish', 'store'): 31,
#  ('store', 'update'): 2,
#  ('update', 'automatically'): 1,
#  ('automatically', 'publish'): 1,
#  ('publish', 'action'): 1,
#  ('action', 'option'): 2,
#  ('option', 'issue'): 1,
#  ('portal', 'store'): 2,
#  ('store', 'want'): 2,
#  ('want', 'publish'): 2,
#  ('publish', 'draft'): 5,
#  ('store', 'condition'): 1,
#  ('condition', 'exist'): 1,
#  ('exist', 'publish'): 3,
#  ('publish', 'exist'): 1,
#  ('exist', 'click'): 2,
#  ('click', 'action'): 1,
#  ('option', 'click'): 1,
#  ('click', 'publish'): 2,
#  ('publish', 'publish'): 1,
#  ('publish', 'modal'): 1,
#  ('modal', 'appear'): 1,
#  ('appear', 'type'): 1,
#  ('type', 'publish'): 1,
#  ('publish', 'click'): 1,
#  ('publish', 'button'): 1,
#  ('button', 'success'): 2,
#  ('success', 'pop'): 1,
#  ('pop', 'trigger'): 1,
#  ('trigger', 'publish'): 1,
#  ('display', 'note'): 1,
#  ('issue', 'also'): 9,
#  ('also', 'happen'): 15,
#  ('environment', 'workaround'): 1,
#  ('workaround', 'issue'): 8,
#  ('issue', 'refresh'): 1,
#  ('refresh', 'portal'): 1,
#  ('portal', 'access'): 6,
#  ('access', 'store'): 4,
#  ('store', 'section'): 3,
#  ('section', 'portal'): 4,
#  ('join',): 4,
#  ('checkout',): 3,
#  ('take',): 14,
#  ('long',): 11,
#  ('pending',): 7,
#  ('order',): 81,
#  ('input',): 57,
#  ('pay',): 4,
#  ('inform',): 5,
#  ('process',): 21,
#  ('may',): 2,
#  ('minutes',): 11,
#  ('actually',): 16,
#  ('untill',): 1,
#  ('two',): 8,
#  ('hours',): 6,
#  ('subscription', 'join'): 1,
#  ('join', 'prime'): 4,
#  ('prime', 'use'): 2,
#  ('use', 'checkout'): 2,
#  ('checkout', 'take'): 1,
#  ('take', 'long'): 1,
#  ('long', 'pending'): 1,
#  ('pending', 'order'): 3,
#  ('order', 'player'): 2,
#  ('player', 'go'): 4,
#  ('go', 'prime'): 1,
#  ('prime', 'click'): 1,
#  ('click', 'join'): 1,
#  ('subscription', 'input'): 1,
#  ('input', 'require'): 1,
#  ('field', 'click'): 2,
#  ('click', 'pay'): 1,
#  ('pay', 'player'): 1,
#  ('player', 'get'): 4,
#  ('get', 'message'): 8,
#  ('message', 'inform'): 4,
#  ('inform', 'payment'): 1,
#  ('payment', 'still'): 1,
#  ('still', 'process'): 1,
#  ('process', 'may'): 1,
#  ('may', 'take'): 1,
#  ('take', 'minutes'): 1,
#  ('minutes', 'actually'): 1,
#  ('actually', 'untill'): 1,
#  ('untill', 'two'): 1,
#  ('two', 'hours'): 1,
#  ('hours', 'order'): 1,
#  ('order', 'still'): 1,
#  ('still', 'pending'): 1,
#  ('pending', 'note'): 1,
#  ('occur', 'join'): 1,
#  ('prime', 'launcher'): 1,
#  ('space',): 42,
#  ('board',): 1,
#  ('subtypes',): 1,
#  ('far',): 4,
#  ('stg', 'ap'): 18,
#  ('ap', 'ugc'): 3,
#  ('ugc', 'type'): 1,
#  ('type', 'detail'): 2,
#  ('detail', 'space'): 1,
#  ('space', 'board'): 1,
#  ('board', 'type'): 1,
#  ('detail', 'subtypes'): 1,
#  ('subtypes', 'far'): 1,
#  ('far', 'portal'): 1,
#  ('ue',): 33,
#  ('login',): 237,
#  ('oauth',): 22,
#  ('token',): 22,
#  ('current',): 39,
#  ('version',): 45,
#  ('break',): 12,
#  ('old',): 16,
#  ('authorization',): 5,
#  ('flow',): 17,
#  ('quick',): 4,
#  ('fix',): 42,
#  ('back',): 46,
#  ('ue', 'login'): 1,
#  ('login', 'launcher'): 19,
#  ('launcher', 'work'): 3,
#  ('work', 'iam'): 2,
#  ('iam', 'v'): 8,
#  ('v', 'oauth'): 6,
#  ('oauth', 'token'): 9,
#  ('token', 'endpoint'): 2,
#  ('endpoint', 'current'): 2,
#  ('current', 'sdk'): 2,
#  ('sdk', 'version'): 2,
#  ('version', 'break'): 2,
#  ('break', 'integration'): 2,
#  ('integration', 'launcher'): 2,
#  ('launcher', 'launcher'): 13,
#  ('launcher', 'still'): 7,
#  ('still', 'use'): 7,
#  ('use', 'old'): 6,
#  ('old', 'authorization'): 2,
#  ('authorization', 'code'): 3,
#  ('code', 'flow'): 2,
#  ('flow', 'use'): 2,
#  ('use', 'iam'): 6,
#  ('iam', 'oauth'): 6,
#  ('token', 'sdk'): 2,
#  ('sdk', 'use'): 2,
#  ('token', 'quick'): 2,
#  ('quick', 'fix'): 4,
#  ('fix', 'change'): 2,
#  ('change', 'back'): 2,
#  ('back', 'login'): 4,
#  ('launcher', 'use'): 5,
#  ('token', 'launcher'): 3,
#  ('unity', 'login'): 1,
#  ('achievement',): 62,
#  ('difference',): 7,
#  ('model',): 8,
#  ('achievementcode',): 2,
#  ('total',): 11,
#  ('distance',): 1,
#  ('latestvalue',): 2,
#  ('achievedat',): 2,
#  ('magellan',): 1,
#  ('elcano',): 1,
#  ('champion',): 1,
#  ('public',): 28,
#  ('class',): 1,
#  ('userachievement',): 1,
#  ('datamember',): 4,
#  ('string',): 33,
#  ('set',): 67,
#  ('int',): 3,
#  ('progress',): 5,
#  ('unlock',): 3,
#  ('different',): 33,
#  ('could',): 13,
#  ('parse',): 4,
#  ('sdk', 'achievement'): 1,
#  ('achievement', 'fix'): 2,
#  ('fix', 'difference'): 1,
#  ('difference', 'achievement'): 1,
#  ('achievement', 'model'): 1,
#  ('model', 'backend'): 1,
#  ('backend', 'sdk'): 1,
#  ('sdk', 'example'): 1,
#  ('example', 'backend'): 1,
#  ('backend', 'model'): 1,
#  ('model', 'id'): 1,
#  ('id', 'achievementcode'): 1,
#  ('achievementcode', 'total'): 1,
#  ('total', 'distance'): 1,
#  ('distance', 'status'): 1,
#  ('status', 'latestvalue'): 1,
#  ('latestvalue', 'achievedat'): 1,
#  ('achievedat', 'name'): 1,
#  ('name', 'en'): 1,
#  ('en', 'magellan'): 1,
#  ('magellan', 'elcano'): 1,
#  ('elcano', 'champion'): 1,
#  ('champion', 'sdk'): 1,
#  ('sdk', 'model'): 1,
#  ('model', 'public'): 1,
#  ('public', 'class'): 1,
#  ('class', 'userachievement'): 1,
#  ('userachievement', 'datamember'): 1,
#  ('datamember', 'public'): 4,
#  ('public', 'string'): 2,
#  ('string', 'achievementcode'): 1,
#  ('achievementcode', 'get'): 1,
#  ('get', 'set'): 4,
#  ('set', 'datamember'): 3,
#  ('string', 'achievedat'): 1,
#  ('achievedat', 'get'): 1,
#  ('public', 'int'): 2,
#  ('int', 'latestvalue'): 1,
#  ('latestvalue', 'get'): 1,
#  ('int', 'status'): 1,
#  ('status', 'get'): 1,
#  ('set', 'progress'): 1,
#  ('progress', 'unlock'): 1,
#  ('unlock', 'different'): 1,
#  ('different', 'make'): 1,
#  ('make', 'backend'): 1,
#  ('backend', 'response'): 1,
#  ('response', 'could'): 1,
#  ('could', 'parse'): 1,
#  ('parse', 'sdk'): 2,
#  ('invalid',): 111,
#  ('env',): 10,
#  ('sure',): 5,
#  ('later',): 13,
#  ('invalid', 'sdk'): 2,
#  ('sdk', 'unity'): 3,
#  ('unity', 'achievement'): 1,
#  ('fix', 'achievement'): 1,
#  ('achievement', 'integration'): 2,
#  ('integration', 'test'): 3,
#  ('test', 'demo'): 1,
#  ('demo', 'env'): 2,
#  ('env', 'achievement'): 1,
#  ('fail', 'unity'): 1,
#  ('sdk', 'sure'): 1,
#  ('sure', 'root'): 1,
#  ('cause', 'update'): 1,
#  ('update', 'later'): 1,
#  ('later', 'sdk'): 1,
#  ('unable',): 55,
#  ('chinese',): 10,
#  ...}

# %%
with open('./Output/MyDFDict.csv', 'w') as f:
    for key in DF.keys():
        f.write("%s,%s\n"%(key,DF[key]))

# %%
n_document = len(listOfSummary)

def calc_IDF(__n_document, __DF):
    IDF_Dict = {}
    for term in __DF:
        IDF_Dict[term] = np.log(__n_document / (__DF[term] + 1))
    return IDF_Dict
  
#Stores the idf dictionary
IDF = calc_IDF(n_document, DF)

# %%
with open('./Output/MyIDFDict.csv', 'w') as f:
    for key in IDF.keys():
        f.write("%s,%s\n"%(key,IDF[key]))

# %%
def compute_jaccard(str1, str2):
    himpunan1 = set(str1)
    himpunan2 = set(str2)
    irisan = himpunan1.intersection(himpunan2)
    IDF_VAL = 0.0
    for key in irisan:
        IDF_VAL = IDF_VAL + IDF[key]
    IDF_VAL = IDF_VAL/(len(irisan)+1)
    gabungan = himpunan1.union(himpunan2)
#     jaccard = IDF_VAL
    jaccard = (len(irisan)/float(len(gabungan))) * IDF_VAL
    
    return jaccard

# %%
import itertools

sim_df = pd.DataFrame()

for col_pair in itertools.combinations_with_replacement(listOfSummary,2):
    strOfCol = str(col_pair)
    
    u0 = col_pair[0]
    u1 = col_pair[1]
    sim_df.loc[str(col_pair[0]), str(col_pair[1])] = compute_jaccard(u0, u1)

# %%
sim_df = sim_df.fillna(0)

# %%
dist = np.array(sim_df)

print(dist)
# Out:
# [[3.54419121e+00 2.96009946e-01 2.02921430e-02 ... 2.64561350e-02
#   4.54590716e-02 2.87141734e-02]
#  [0.00000000e+00 3.37874723e+00 4.02154493e-02 ... 3.65575684e-02
#   4.80074014e-02 3.75904407e-03]
#  [0.00000000e+00 0.00000000e+00 4.50476434e+00 ... 1.18333416e-02
#   2.32492527e-02 3.54921003e-02]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 3.76130488e+00
#   5.92670225e-01 1.43396644e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   3.86151648e+00 1.27650302e-01]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 4.32428754e+00]]

# %%
sim_df.to_csv("./Output/jcidf_matrix.csv")

# %% [markdown]
# ## Agglomerative Hierarchical Clustering

# %%
linkage_matrix = ward(dist) # replace with complete, single, or other scipy.cluster.hierarchical algorithms

# %% [markdown]
# ## Visualization
#
# Dendrogram visualization. We visualize the titles of each paper next to the corresponding leaf to qualitatively evaluate the clustering.
#
# Changing the `color_threshold` kwarg in the call to `dendrogram()` will affect how the clusters are displayed by increasing or decreasing the
# minimum distance necessary for `dendrogram()` to color a cluster differently.

# %%
# sys.setrecursionlimit(10000)
# MAX_COPHENETIC_DIST = max(linkage_matrix[:,2]) * 0.39 # max distance between points to be considered together. can be tuned.
# MAX_TITLE_LEN = 200

# fig, ax = plt.subplots(figsize=(15, 80)) # set size
# ax = dendrogram(linkage_matrix, orientation="right", color_threshold=MAX_COPHENETIC_DIST, leaf_font_size=4,
#                 labels=Summary.apply(lambda x: x if len(x) < MAX_TITLE_LEN else x[:MAX_TITLE_LEN  - 3] + "...").tolist())

# plt.tick_params(axis= 'x', which='both',  bottom='off', top='off',labelbottom='off')

# plt.tight_layout() #show plot with tight layout
# plt.savefig('./Output/jaccard-idf-coeff-ward.png', dpi=300)

# %% [markdown]
# # Analysis
#
# We now take the raw clusters achieved and use the silhouette score and elbow method to evaluate.

# %%
def silhouette_k(distance_matrix, linkage_matrix, max_k=20):
    scores = []
    for i in range(2, max_k+1):
        clusters = fcluster(linkage_matrix, i, criterion='maxclust')
        score = silhouette_score(distance_matrix, clusters, metric='precomputed')
        print("Silhouette score with {} clusters:".format(i), score)
        scores.append(score)
    plt.title("Silhouette score vs. number of clusters")
    plt.xlabel("# of clusters")
    plt.ylabel("Score (higher is better)")
    plt.plot(np.arange(2, max_k+1), scores)
    plt.show()
    return scores

# %%
np.fill_diagonal(dist, 0)
_ = silhouette_k(dist, linkage_matrix)
# Out:
# Silhouette score with 2 clusters: -0.9428156577526194
# Silhouette score with 3 clusters: -0.9587076707589862
# Silhouette score with 4 clusters: -0.9757353943307068
# Silhouette score with 5 clusters: -0.9771988456229506
# Silhouette score with 6 clusters: -0.9744853924986893
# Silhouette score with 7 clusters: -0.9732201717816347
# Silhouette score with 8 clusters: -0.9782123802334275
# Silhouette score with 9 clusters: -0.9783869274597841
# Silhouette score with 10 clusters: -0.9814555758113829
# Silhouette score with 11 clusters: -0.9801787633459489
# Silhouette score with 12 clusters: -0.978759811335437
# Silhouette score with 13 clusters: -0.9778381793277238
# Silhouette score with 14 clusters: -0.9764665211470646
# Silhouette score with 15 clusters: -0.9748526148545618
# Silhouette score with 16 clusters: -0.9733141533161003
# Silhouette score with 17 clusters: -0.9717756917776387
# Silhouette score with 18 clusters: -0.9702372302391772
# Silhouette score with 19 clusters: -0.9707692307692307
# Silhouette score with 20 clusters: -0.9692307692307692

# %%
#Importing all the neccesary libraries
import numpy as np 
import pandas as pd 
import csv

import os
print(os.listdir("input"))

import regex as re
import string
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.stem import SnowballStemmer
# from wordcloud import WordCloud

# viz
import matplotlib.pyplot as plt
# %matplotlib inline
import sys

# for clustering
from scipy.cluster.hierarchy import ward, dendrogram, fcluster, single, complete, average, weighted
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial.distance import squareform
from sklearn.metrics import silhouette_score
# Out:
# ['.ipynb_checkpoints', 'Bug report.csv', 'JIRA-ALL.csv', 'JIRA-BUG.csv', 'mozilla_firefox']

# %%
data=pd.read_csv('Input/JIRA-BUG.csv')
data = data.reset_index()

# %%
cols_of_interest=["Summary", "Status","Description","Priority","Resolution", "Issue Type", "Bug Location"]
data=data[cols_of_interest]
print(data.shape)
data.head()
# Out:
# (651, 7)
#                                              Summary       Status  \
# 0  [Dev][Demo][Admin Portal][Edit Bundle items]: ...        To Do
# 1  [Dev][Admin Portal][Create New][Create From ex...  In Progress
# 2  Duplicate items while using Search items by ke...        To Do
# 3  [AP] Default language and default region of st...           QA
# 4  [Unity][SDK] Single draft store makes subscrip...        To Do
#
#                                          Description Priority Resolution  \
# 0  This issue occurs on *Add new bundle items.*\n...       P1        NaN
# 1  This issue occurs on Create new Role and Creat...       P1        NaN
# 2  While making script for cleanup, we found that...       P2        NaN
# 3  When we open Stores menu and look at the store...       P1        NaN
# 4  The restriction of single draft store makes su...       P1        NaN
#
#   Issue Type     Bug Location
# 0        Bug     Admin Portal
# 1        Bug     Admin Portal
# 2        Bug  Automation Test
# 3        Bug     Admin Portal
# 4        Bug              SDK

# %%
fig = plt.figure(figsize=(8,6))
data.groupby('Bug Location').Status.count().plot.bar(ylim=0)
plt.show()

# %%
data.Description = data.Description.fillna("0")
data.isnull().sum()
# Out:
# Summary          0
# Status           0
# Description      0
# Priority         0
# Resolution      97
# Issue Type       0
# Bug Location     0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Summary          0
# Status           0
# Description      0
# Priority         0
# Resolution      97
# Issue Type       0
# Bug Location     0
# dtype: int64

# %% [markdown]
# **Text data preprocessing steps**
#
# 1- Data Cleaning(either using regex or BeautifulSoup):
# a) Removing HTML characters.
# b) Removing punctuation.
# c) Decoding encoded data.
# d) Split attached words.
# e) Removing URLs.
# f) Apostrophe removal.
# g) Removing Expressions.
# h) Uppercase & Lowercase letters
# i) Numbers such as amounts and data.
#
# 2- Data Tokenization(using word_tokenize in nltk.tokenize)
# Segregation of text into individual words i.e tokens.
#
# 3- Stopword Removal(using stopwords in nltk.corpus)
# Discarding too common words or words which are not going to be helpful in our analysis.
#
# 4- Stemming(using WordNetLemmatizer in nltk.stem)
# Combining different variants of words into a single parent word that conveys same meaning.

# %%
stops = set(stopwords.words("english"))

# %%
data['Concat'] = data.Summary +" "+ data.Description+" "+data["Bug Location"]
data.to_csv("./Output/data_concat.csv")

# %%
def clean_Description(content):
#     content = table.Description
    #Converting text to lowercase characters
    content = content.apply(lambda x: x.lower())
    #Removing HTML tags
    content = content.apply(lambda x: re.sub(r'\<[^<>]*\>','',x))
    #Removing any character which does not match to letter,digit or underscore
    content = content.apply(lambda x: re.sub(r'^\W+|\W+$',' ',x))
    #Removing space,newline,tab
    content = content.apply(lambda x: re.sub(r'\s',' ',x))
    #Removing punctuation
    content = content.apply(lambda x: re.sub(r'[^a-zA-Z0-9]',' ',x))
    #Removing numeric
    content = content.apply(lambda x: re.sub(r'[0-9]','',x))
    #Tokenizing data
    content = content.apply(lambda x: word_tokenize(x))
    #Removing stopwords
    content = content.apply(lambda x: [i for i in x if i not in stops])
    type(content)
    return(content)

# %%
dataClean = pd.DataFrame()
data['Concat'] = clean_Description(data['Concat'])
dataClean['Concat'] = data['Concat']

# %%
dataClean.head()
# Out:
#                                               Concat
# 0  [dev, demo, portal, edit, bundle, items, add, ...
# 1  [dev, portal, create, new, create, existing, a...
# 2  [duplicate, items, using, search, items, keywo...
# 3  [ap, default, language, default, region, store...
# 4  [unity, sdk, single, draft, store, makes, subs...

# %% [markdown]
# ## Stemming

# %%
data.dtypes
# Out:
# Summary         object
# Status          object
# Description     object
# Priority        object
# Resolution      object
# Issue Type      object
# Bug Location    object
# Concat          object
# dtype: object

# %%
wordnet = WordNetLemmatizer()
dataClean.Concat = dataClean.Concat.apply(lambda x:[wordnet.lemmatize(i,pos='v') for i in x])

# %%
dataClean['Concat'] = dataClean['Concat'].astype(str)
dataClean['Concat'] = dataClean['Concat'].apply(lambda x: re.sub(r'\s',' ',x))
dataClean['Concat'] = dataClean['Concat'].apply(lambda x: re.sub(r'[^a-zA-Z0-9]',' ',x))
dataClean['Concat'] = dataClean['Concat'].apply(lambda x: re.sub(r'^\W+|\W+$',' ',x))

# %%
dataClean.head()
dataClean.to_csv("./Output/token_concat.csv")

# %%
from nltk.util import everygrams
def ngramconvert(df,n=2,col=""):
    for item in df.columns:
        df[col]=df[item].apply(lambda sentence: list(everygrams(sentence.split(), max_len=n)))
    return df

# %%
new_df = ngramconvert(dataClean,4,"nGram")
new_df.head()
# Out:
#                                               Concat  \
# 0   dev    demo    portal    edit    bundle    it...
# 1   dev    portal    create    new    create    e...
# 2   duplicate    items    use    search    items ...
# 3   ap    default    language    default    regio...
# 4   unity    sdk    single    draft    store    m...
#
#                                                nGram
# 0  [(dev,), (demo,), (portal,), (edit,), (bundle,...
# 1  [(dev,), (portal,), (create,), (new,), (create...
# 2  [(duplicate,), (items,), (use,), (search,), (i...
# 3  [(ap,), (default,), (language,), (default,), (...
# 4  [(unity,), (sdk,), (single,), (draft,), (store...

# %%
dataClean.head()
# Out:
#                                               Concat  \
# 0   dev    demo    portal    edit    bundle    it...
# 1   dev    portal    create    new    create    e...
# 2   duplicate    items    use    search    items ...
# 3   ap    default    language    default    regio...
# 4   unity    sdk    single    draft    store    m...
#
#                                                nGram
# 0  [(dev,), (demo,), (portal,), (edit,), (bundle,...
# 1  [(dev,), (portal,), (create,), (new,), (create...
# 2  [(duplicate,), (items,), (use,), (search,), (i...
# 3  [(ap,), (default,), (language,), (default,), (...
# 4  [(unity,), (sdk,), (single,), (draft,), (store...

# %%
# desc = ' '
# for x in data.Concat:
#     for y in x:
#         desc+=' '+y

# %%
# plt.figure(figsize=(8,10))
# wc = WordCloud(max_words=1000,random_state=1).generate(desc)
# plt.imshow(wc)
# plt.show()

# %%
Summary = dataClean.Concat.astype(str)
listOfSummary = dataClean.nGram

# %%
listOfSummary
# Out:
# 0      [(dev,), (demo,), (portal,), (edit,), (bundle,...
# 1      [(dev,), (portal,), (create,), (new,), (create...
# 2      [(duplicate,), (items,), (use,), (search,), (i...
# 3      [(ap,), (default,), (language,), (default,), (...
# 4      [(unity,), (sdk,), (single,), (draft,), (store...
#                              ...
# 646    [(stg,), (launcher,), (launcher,), (start,), (...
# 647    [(stg,), (launcher,), (set,), (revert,), (last...
# 648    [(stg,), (ap,), (portal,), (feature,), (conten...
# 649    [(stg,), (ap,), (option,), (update,), (client,...
# 650    [(backend,), (get,), (use,), (different,), (na...
# Name: nGram, Length: 651, dtype: object

# %% [markdown]
# # Hiearchical Clustering

# %% [markdown]
# ## Jaccard Coeffient

# %%
import itertools
def compute_jaccard(str1, str2):
    himpunan1 = set(str1)
    himpunan2 = set(str2)
    irisan = himpunan1.intersection(himpunan2)
    gabungan = himpunan1.union(himpunan2)
    jaccard = len(irisan)/float(len(gabungan))
    
    return jaccard

# %%
sim_df = pd.DataFrame()

for col_pair in itertools.combinations_with_replacement(listOfSummary,2):
    strOfCol = str(col_pair)
    
    u0 = col_pair[0]
    u1 = col_pair[1]
    sim_df.loc[str(col_pair[0]), str(col_pair[1])] = compute_jaccard(u0, u1)

# %%
np.savetxt("./Output/distance_matrix_before_fillna.csv", np.array(sim_df), delimiter=",")

# %%
sim_df = sim_df.fillna(0)

# %%
dist = np.array(sim_df)
print(dist)
# Out:
# [[1.         0.08510638 0.00611621 ... 0.01169591 0.01587302 0.00678733]
#  [0.         1.         0.01219512 ... 0.01526718 0.01672241 0.00274725]
#  [0.         0.         1.         ... 0.00347222 0.00615385 0.01041667]
#  ...
#  [0.         0.         0.         ... 1.         0.12418301 0.03053435]
#  [0.         0.         0.         ... 0.         1.         0.02784223]
#  [0.         0.         0.         ... 0.         0.         1.        ]]

# %%
# ndist = dist[:, ~np.isnan(dist).any(axis=0)]
# # print(ndist)

# %%
np.savetxt("./Output/distance_matrix.csv", dist, delimiter=",")

# %% [markdown]
# ## Agglomerative Hierarchical Clustering

# %%
linkage_matrix = weighted(dist) # replace with complete, single, or other scipy.cluster.hierarchical algorithms

# %% [markdown]
# ## Visualization
#
# Dendrogram visualization. We visualize the titles of each paper next to the corresponding leaf to qualitatively evaluate the clustering.
#
# Changing the `color_threshold` kwarg in the call to `dendrogram()` will affect how the clusters are displayed by increasing or decreasing the
# minimum distance necessary for `dendrogram()` to color a cluster differently.

# %%
# sys.setrecursionlimit(10000)
# MAX_COPHENETIC_DIST = max(linkage_matrix[:,2]) * 0.39 # max distance between points to be considered together. can be tuned.
# MAX_TITLE_LEN = 200

# fig, ax = plt.subplots(figsize=(15, 80)) # set size
# ax = dendrogram(linkage_matrix, orientation="right", color_threshold=MAX_COPHENETIC_DIST, leaf_font_size=4, labels=Summary.apply(lambda x: x if len(x) < MAX_TITLE_LEN else x[:MAX_TITLE_LEN  - 3] + "...").tolist())

# plt.tick_params(axis= 'x', which='both',  bottom='off', top='off',labelbottom='off')

# plt.tight_layout() #show plot with tight layout
# plt.savefig('./Output/jaccard-coeff-ward.png', dpi=300)

# %% [markdown]
# # Analysis
#
# We now take the raw clusters achieved and use the silhouette score and elbow method to evaluate.

# %%
def silhouette_k(distance_matrix, linkage_matrix, max_k=20):
    scores = []
    for i in range(2, max_k+1):
        clusters = fcluster(linkage_matrix, i, criterion='maxclust')
        score = silhouette_score(distance_matrix, clusters, metric='precomputed')
        print("Silhouette score with {} clusters:".format(i), score)
        scores.append(score)
    plt.title("Silhouette score vs. number of clusters")
    plt.xlabel("# of clusters")
    plt.ylabel("Score (higher is better)")
    plt.plot(np.arange(2, max_k+1), scores)
    plt.show()
    return scores

# %%
np.fill_diagonal(dist, 0)
_ = silhouette_k(dist, linkage_matrix)
# Out:
# Silhouette score with 2 clusters: -0.4284944091497426
# Silhouette score with 3 clusters: -0.7046268995597265
# Silhouette score with 4 clusters: -0.8731327255559108
# Silhouette score with 5 clusters: -0.9856186172782924
# Silhouette score with 6 clusters: -0.9846154134562807
# Silhouette score with 7 clusters: -0.9830530350176699
# Silhouette score with 8 clusters: -0.9815145734792083
# Silhouette score with 9 clusters: -0.981510316422064
# Silhouette score with 10 clusters: -0.9825937700879924
# Silhouette score with 11 clusters: -0.9810553085495308
# Silhouette score with 12 clusters: -0.9795168470110693
# Silhouette score with 13 clusters: -0.9783939657275494
# Silhouette score with 14 clusters: -0.976855504189088
# Silhouette score with 15 clusters: -0.9753170426506264
# Silhouette score with 16 clusters: -0.975184805711977
# Silhouette score with 17 clusters: -0.9736463441735154
# Silhouette score with 18 clusters: -0.9721116451341165
# Silhouette score with 19 clusters: -0.9705731835956549
# Silhouette score with 20 clusters: -0.9690347220571934

# %% [markdown]
#  # Hierarchical Clustering Using Jaccard Coefficient and IDF

# %%
def calc_DF(tfDict):
    count_DF = {}
    # Run through each document's tf dictionary and increment countDict's (term, doc) pair
    for document in tfDict:
        for term in document:
            if term in count_DF:
                count_DF[term] += 1
            else:
                count_DF[term] = 1
    return count_DF

DF = calc_DF(listOfSummary)
DF
# Out:
# {('dev',): 104,
#  ('demo',): 330,
#  ('portal',): 591,
#  ('edit',): 78,
#  ('bundle',): 26,
#  ('items',): 45,
#  ('add',): 161,
#  ('item',): 198,
#  ('type',): 71,
#  ('code',): 134,
#  ('season',): 2,
#  ('subscription',): 117,
#  ('return',): 59,
#  ('error',): 269,
#  ('response',): 39,
#  ('issue',): 193,
#  ('occur',): 126,
#  ('new',): 167,
#  ('already',): 69,
#  ('create',): 190,
#  ('draft',): 42,
#  ('store',): 182,
#  ('view',): 52,
#  ('please',): 110,
#  ('notice',): 134,
#  ('note',): 97,
#  ('also',): 55,
#  ('provide',): 7,
#  ('suitable',): 1,
#  ('message',): 156,
#  ('one',): 46,
#  ('show',): 139,
#  ('fail',): 125,
#  ('update',): 182,
#  ('try',): 113,
#  ('accountid',): 24,
#  ('see',): 101,
#  ('attachment',): 75,
#  ('detail',): 134,
#  ('dev', 'demo'): 15,
#  ('demo', 'portal'): 3,
#  ('portal', 'edit'): 1,
#  ('edit', 'bundle'): 1,
#  ('bundle', 'items'): 6,
#  ('items', 'add'): 1,
#  ('add', 'item'): 12,
#  ('item', 'type'): 10,
#  ('type', 'code'): 4,
#  ('code', 'season'): 2,
#  ('season', 'subscription'): 2,
#  ('subscription', 'return'): 2,
#  ('return', 'error'): 5,
#  ('error', 'response'): 8,
#  ('response', 'issue'): 1,
#  ('issue', 'occur'): 77,
#  ('occur', 'add'): 3,
#  ('add', 'new'): 12,
#  ('new', 'bundle'): 2,
#  ('items', 'already'): 1,
#  ('already', 'create'): 3,
#  ('create', 'item'): 3,
#  ('item', 'bundle'): 3,
#  ('bundle', 'type'): 2,
#  ('type', 'draft'): 1,
#  ('draft', 'store'): 41,
#  ('store', 'view'): 4,
#  ('view', 'bundle'): 2,
#  ('items', 'please'): 1,
#  ('please', 'notice'): 23,
#  ('notice', 'add'): 6,
#  ('response', 'note'): 1,
#  ('note', 'also'): 12,
#  ('also', 'please'): 1,
#  ('please', 'provide'): 1,
#  ('provide', 'suitable'): 1,
#  ('suitable', 'error'): 1,
#  ('error', 'message'): 61,
#  ('message', 'one'): 2,
#  ('one', 'show'): 1,
#  ('show', 'fail'): 9,
#  ('fail', 'update'): 3,
#  ('update', 'item'): 3,
#  ('item', 'try'): 2,
#  ('try', 'accountid'): 1,
#  ('accountid', 'please'): 2,
#  ('please', 'see'): 43,
#  ('see', 'attachment'): 47,
#  ('attachment', 'detail'): 61,
#  ('detail', 'portal'): 27,
#  ('dev', 'demo', 'portal'): 1,
#  ('demo', 'portal', 'edit'): 1,
#  ('portal', 'edit', 'bundle'): 1,
#  ('edit', 'bundle', 'items'): 1,
#  ('bundle', 'items', 'add'): 1,
#  ('items', 'add', 'item'): 1,
#  ('add', 'item', 'type'): 2,
#  ('item', 'type', 'code'): 3,
#  ('type', 'code', 'season'): 2,
#  ('code', 'season', 'subscription'): 2,
#  ('season', 'subscription', 'return'): 2,
#  ('subscription', 'return', 'error'): 2,
#  ('return', 'error', 'response'): 2,
#  ('error', 'response', 'issue'): 1,
#  ('response', 'issue', 'occur'): 1,
#  ('issue', 'occur', 'add'): 2,
#  ('occur', 'add', 'new'): 1,
#  ('add', 'new', 'bundle'): 2,
#  ('new', 'bundle', 'items'): 2,
#  ('bundle', 'items', 'already'): 1,
#  ('items', 'already', 'create'): 1,
#  ('already', 'create', 'item'): 1,
#  ('create', 'item', 'bundle'): 1,
#  ('item', 'bundle', 'type'): 1,
#  ('bundle', 'type', 'draft'): 1,
#  ('type', 'draft', 'store'): 1,
#  ('draft', 'store', 'view'): 2,
#  ('store', 'view', 'bundle'): 2,
#  ('view', 'bundle', 'items'): 1,
#  ('bundle', 'items', 'please'): 1,
#  ('items', 'please', 'notice'): 1,
#  ('please', 'notice', 'add'): 1,
#  ('notice', 'add', 'item'): 2,
#  ('error', 'response', 'note'): 1,
#  ('response', 'note', 'also'): 1,
#  ('note', 'also', 'please'): 1,
#  ('also', 'please', 'provide'): 1,
#  ('please', 'provide', 'suitable'): 1,
#  ('provide', 'suitable', 'error'): 1,
#  ('suitable', 'error', 'message'): 1,
#  ('error', 'message', 'one'): 1,
#  ('message', 'one', 'show'): 1,
#  ('one', 'show', 'fail'): 1,
#  ('show', 'fail', 'update'): 1,
#  ('fail', 'update', 'item'): 2,
#  ('update', 'item', 'try'): 2,
#  ('item', 'try', 'accountid'): 1,
#  ('try', 'accountid', 'please'): 1,
#  ('accountid', 'please', 'see'): 1,
#  ('please', 'see', 'attachment'): 41,
#  ('see', 'attachment', 'detail'): 45,
#  ('attachment', 'detail', 'portal'): 24,
#  ('dev', 'demo', 'portal', 'edit'): 1,
#  ('demo', 'portal', 'edit', 'bundle'): 1,
#  ('portal', 'edit', 'bundle', 'items'): 1,
#  ('edit', 'bundle', 'items', 'add'): 1,
#  ('bundle', 'items', 'add', 'item'): 1,
#  ('items', 'add', 'item', 'type'): 1,
#  ('add', 'item', 'type', 'code'): 2,
#  ('item', 'type', 'code', 'season'): 2,
#  ('type', 'code', 'season', 'subscription'): 2,
#  ('code', 'season', 'subscription', 'return'): 2,
#  ('season', 'subscription', 'return', 'error'): 2,
#  ('subscription', 'return', 'error', 'response'): 2,
#  ('return', 'error', 'response', 'issue'): 1,
#  ('error', 'response', 'issue', 'occur'): 1,
#  ('response', 'issue', 'occur', 'add'): 1,
#  ('issue', 'occur', 'add', 'new'): 1,
#  ('occur', 'add', 'new', 'bundle'): 1,
#  ('add', 'new', 'bundle', 'items'): 2,
#  ('new', 'bundle', 'items', 'already'): 1,
#  ('bundle', 'items', 'already', 'create'): 1,
#  ('items', 'already', 'create', 'item'): 1,
#  ('already', 'create', 'item', 'bundle'): 1,
#  ('create', 'item', 'bundle', 'type'): 1,
#  ('item', 'bundle', 'type', 'draft'): 1,
#  ('bundle', 'type', 'draft', 'store'): 1,
#  ('type', 'draft', 'store', 'view'): 1,
#  ('draft', 'store', 'view', 'bundle'): 1,
#  ('store', 'view', 'bundle', 'items'): 1,
#  ('view', 'bundle', 'items', 'please'): 1,
#  ('bundle', 'items', 'please', 'notice'): 1,
#  ('items', 'please', 'notice', 'add'): 1,
#  ('please', 'notice', 'add', 'item'): 1,
#  ('notice', 'add', 'item', 'type'): 1,
#  ('return', 'error', 'response', 'note'): 1,
#  ('error', 'response', 'note', 'also'): 1,
#  ('response', 'note', 'also', 'please'): 1,
#  ('note', 'also', 'please', 'provide'): 1,
#  ('also', 'please', 'provide', 'suitable'): 1,
#  ('please', 'provide', 'suitable', 'error'): 1,
#  ('provide', 'suitable', 'error', 'message'): 1,
#  ('suitable', 'error', 'message', 'one'): 1,
#  ('error', 'message', 'one', 'show'): 1,
#  ('message', 'one', 'show', 'fail'): 1,
#  ('one', 'show', 'fail', 'update'): 1,
#  ('show', 'fail', 'update', 'item'): 1,
#  ('fail', 'update', 'item', 'try'): 2,
#  ('update', 'item', 'try', 'accountid'): 1,
#  ('item', 'try', 'accountid', 'please'): 1,
#  ('try', 'accountid', 'please', 'see'): 1,
#  ('accountid', 'please', 'see', 'attachment'): 1,
#  ('please', 'see', 'attachment', 'detail'): 40,
#  ('see', 'attachment', 'detail', 'portal'): 15,
#  ('exist',): 48,
#  ('able',): 73,
#  ('use',): 202,
#  ('role',): 55,
#  ('name',): 82,
#  ('clone',): 39,
#  ('dev', 'portal'): 1,
#  ('portal', 'create'): 1,
#  ('create', 'new'): 62,
#  ('new', 'create'): 3,
#  ('create', 'exist'): 4,
#  ('exist', 'able'): 1,
#  ('able', 'use'): 7,
#  ('use', 'role'): 3,
#  ('role', 'name'): 2,
#  ('name', 'already'): 2,
#  ('already', 'exist'): 4,
#  ('exist', 'issue'): 1,
#  ('occur', 'create'): 3,
#  ('new', 'role'): 7,
#  ('role', 'create'): 4,
#  ('exist', 'try'): 2,
#  ('try', 'create'): 10,
#  ('role', 'exist'): 1,
#  ('exist', 'clone'): 1,
#  ('clone', 'please'): 1,
#  ('notice', 'able'): 2,
#  ('exist', 'please'): 2,
#  ('dev', 'portal', 'create'): 1,
#  ('portal', 'create', 'new'): 1,
#  ('create', 'new', 'create'): 2,
#  ('new', 'create', 'exist'): 1,
#  ('create', 'exist', 'able'): 1,
#  ('exist', 'able', 'use'): 1,
#  ('able', 'use', 'role'): 2,
#  ('use', 'role', 'name'): 2,
#  ('role', 'name', 'already'): 2,
#  ('name', 'already', 'exist'): 2,
#  ('already', 'exist', 'issue'): 1,
#  ('exist', 'issue', 'occur'): 1,
#  ('issue', 'occur', 'create'): 2,
#  ('occur', 'create', 'new'): 1,
#  ('create', 'new', 'role'): 7,
#  ('new', 'role', 'create'): 2,
#  ('role', 'create', 'exist'): 1,
#  ('create', 'exist', 'try'): 1,
#  ('exist', 'try', 'create'): 1,
#  ('try', 'create', 'new'): 7,
#  ('role', 'create', 'new'): 1,
#  ('new', 'role', 'exist'): 1,
#  ('role', 'exist', 'clone'): 1,
#  ('exist', 'clone', 'please'): 1,
#  ('clone', 'please', 'notice'): 1,
#  ('please', 'notice', 'able'): 1,
#  ('notice', 'able', 'use'): 1,
#  ('already', 'exist', 'please'): 1,
#  ('exist', 'please', 'see'): 1,
#  ('dev', 'portal', 'create', 'new'): 1,
#  ('portal', 'create', 'new', 'create'): 1,
#  ('create', 'new', 'create', 'exist'): 1,
#  ('new', 'create', 'exist', 'able'): 1,
#  ('create', 'exist', 'able', 'use'): 1,
#  ('exist', 'able', 'use', 'role'): 1,
#  ('able', 'use', 'role', 'name'): 2,
#  ('use', 'role', 'name', 'already'): 2,
#  ('role', 'name', 'already', 'exist'): 2,
#  ('name', 'already', 'exist', 'issue'): 1,
#  ('already', 'exist', 'issue', 'occur'): 1,
#  ('exist', 'issue', 'occur', 'create'): 1,
#  ('issue', 'occur', 'create', 'new'): 1,
#  ('occur', 'create', 'new', 'role'): 1,
#  ('create', 'new', 'role', 'create'): 2,
#  ('new', 'role', 'create', 'exist'): 1,
#  ('role', 'create', 'exist', 'try'): 1,
#  ('create', 'exist', 'try', 'create'): 1,
#  ('exist', 'try', 'create', 'new'): 1,
#  ('try', 'create', 'new', 'role'): 1,
#  ('new', 'role', 'create', 'new'): 1,
#  ('role', 'create', 'new', 'role'): 1,
#  ('create', 'new', 'role', 'exist'): 1,
#  ('new', 'role', 'exist', 'clone'): 1,
#  ('role', 'exist', 'clone', 'please'): 1,
#  ('exist', 'clone', 'please', 'notice'): 1,
#  ('clone', 'please', 'notice', 'able'): 1,
#  ('please', 'notice', 'able', 'use'): 1,
#  ('notice', 'able', 'use', 'role'): 1,
#  ('name', 'already', 'exist', 'please'): 1,
#  ('already', 'exist', 'please', 'see'): 1,
#  ('exist', 'please', 'see', 'attachment'): 1,
#  ('duplicate',): 13,
#  ('search',): 92,
#  ('keyword',): 4,
#  ('endpoint',): 66,
#  ('pagination',): 13,
#  ('make',): 59,
#  ('script',): 24,
#  ('cleanup',): 1,
#  ('find',): 93,
#  ('data',): 125,
#  ('first',): 22,
#  ('page',): 223,
#  ('next',): 18,
#  ('compare',): 2,
#  ('without',): 33,
#  ('differences',): 1,
#  ('datas',): 1,
#  ('stg',): 32,
#  ('environment',): 20,
#  ('automation',): 25,
#  ('test',): 133,
#  ('duplicate', 'items'): 1,
#  ('items', 'use'): 3,
#  ('use', 'search'): 3,
#  ('search', 'items'): 5,
#  ('items', 'keyword'): 1,
#  ('keyword', 'endpoint'): 1,
#  ('endpoint', 'pagination'): 1,
#  ('pagination', 'make'): 1,
#  ('make', 'script'): 1,
#  ('script', 'cleanup'): 1,
#  ('cleanup', 'find'): 1,
#  ('find', 'search'): 5,
#  ('use', 'pagination'): 1,
#  ('pagination', 'duplicate'): 1,
#  ('duplicate', 'data'): 1,
#  ('data', 'first'): 1,
#  ('first', 'page'): 1,
#  ('page', 'next'): 1,
#  ('next', 'page'): 3,
#  ('page', 'compare'): 1,
#  ('compare', 'data'): 1,
#  ('data', 'pagination'): 1,
#  ('pagination', 'without'): 1,
#  ('without', 'pagination'): 1,
#  ('pagination', 'find'): 2,
#  ('find', 'differences'): 1,
#  ('differences', 'datas'): 1,
#  ('datas', 'exist'): 1,
#  ('exist', 'use'): 1,
#  ('items', 'pagination'): 1,
#  ('find', 'dev'): 1,
#  ('dev', 'stg'): 1,
#  ('stg', 'environment'): 1,
#  ('environment', 'automation'): 1,
#  ('automation', 'test'): 15,
#  ('duplicate', 'items', 'use'): 1,
#  ('items', 'use', 'search'): 1,
#  ('use', 'search', 'items'): 2,
#  ('search', 'items', 'keyword'): 1,
#  ('items', 'keyword', 'endpoint'): 1,
#  ('keyword', 'endpoint', 'pagination'): 1,
#  ('endpoint', 'pagination', 'make'): 1,
#  ('pagination', 'make', 'script'): 1,
#  ('make', 'script', 'cleanup'): 1,
#  ('script', 'cleanup', 'find'): 1,
#  ('cleanup', 'find', 'search'): 1,
#  ('find', 'search', 'items'): 1,
#  ('search', 'items', 'use'): 1,
#  ('items', 'use', 'pagination'): 1,
#  ('use', 'pagination', 'duplicate'): 1,
#  ('pagination', 'duplicate', 'data'): 1,
#  ('duplicate', 'data', 'first'): 1,
#  ('data', 'first', 'page'): 1,
#  ('first', 'page', 'next'): 1,
#  ('page', 'next', 'page'): 1,
#  ('next', 'page', 'compare'): 1,
#  ('page', 'compare', 'data'): 1,
#  ('compare', 'data', 'pagination'): 1,
#  ('data', 'pagination', 'without'): 1,
#  ('pagination', 'without', 'pagination'): 1,
#  ('without', 'pagination', 'find'): 1,
#  ('pagination', 'find', 'differences'): 1,
#  ('find', 'differences', 'datas'): 1,
#  ('differences', 'datas', 'exist'): 1,
#  ('datas', 'exist', 'use'): 1,
#  ('exist', 'use', 'search'): 1,
#  ('search', 'items', 'pagination'): 1,
#  ('items', 'pagination', 'find'): 1,
#  ('pagination', 'find', 'dev'): 1,
#  ('find', 'dev', 'stg'): 1,
#  ('dev', 'stg', 'environment'): 1,
#  ('stg', 'environment', 'automation'): 1,
#  ('environment', 'automation', 'test'): 1,
#  ('duplicate', 'items', 'use', 'search'): 1,
#  ('items', 'use', 'search', 'items'): 1,
#  ('use', 'search', 'items', 'keyword'): 1,
#  ('search', 'items', 'keyword', 'endpoint'): 1,
#  ('items', 'keyword', 'endpoint', 'pagination'): 1,
#  ('keyword', 'endpoint', 'pagination', 'make'): 1,
#  ('endpoint', 'pagination', 'make', 'script'): 1,
#  ('pagination', 'make', 'script', 'cleanup'): 1,
#  ('make', 'script', 'cleanup', 'find'): 1,
#  ('script', 'cleanup', 'find', 'search'): 1,
#  ('cleanup', 'find', 'search', 'items'): 1,
#  ('find', 'search', 'items', 'use'): 1,
#  ('search', 'items', 'use', 'pagination'): 1,
#  ('items', 'use', 'pagination', 'duplicate'): 1,
#  ('use', 'pagination', 'duplicate', 'data'): 1,
#  ('pagination', 'duplicate', 'data', 'first'): 1,
#  ('duplicate', 'data', 'first', 'page'): 1,
#  ('data', 'first', 'page', 'next'): 1,
#  ('first', 'page', 'next', 'page'): 1,
#  ('page', 'next', 'page', 'compare'): 1,
#  ('next', 'page', 'compare', 'data'): 1,
#  ('page', 'compare', 'data', 'pagination'): 1,
#  ('compare', 'data', 'pagination', 'without'): 1,
#  ('data', 'pagination', 'without', 'pagination'): 1,
#  ('pagination', 'without', 'pagination', 'find'): 1,
#  ('without', 'pagination', 'find', 'differences'): 1,
#  ('pagination', 'find', 'differences', 'datas'): 1,
#  ('find', 'differences', 'datas', 'exist'): 1,
#  ('differences', 'datas', 'exist', 'use'): 1,
#  ('datas', 'exist', 'use', 'search'): 1,
#  ('exist', 'use', 'search', 'items'): 1,
#  ('use', 'search', 'items', 'pagination'): 1,
#  ('search', 'items', 'pagination', 'find'): 1,
#  ('items', 'pagination', 'find', 'dev'): 1,
#  ('pagination', 'find', 'dev', 'stg'): 1,
#  ('find', 'dev', 'stg', 'environment'): 1,
#  ('dev', 'stg', 'environment', 'automation'): 1,
#  ('stg', 'environment', 'automation', 'test'): 1,
#  ('ap',): 277,
#  ('default',): 35,
#  ('language',): 27,
#  ('region',): 15,
#  ('display',): 74,
#  ('properly',): 13,
#  ('open',): 55,
#  ('menu',): 57,
#  ('look',): 8,
#  ('list',): 61,
#  ('correctly',): 5,
#  ('id',): 123,
#  ('instead',): 40,
#  ('correct',): 17,
#  ('label',): 5,
#  ('example',): 21,
#  ('english',): 4,
#  ('us',): 18,
#  ('en',): 14,
#  ('ap', 'default'): 2,
#  ('default', 'language'): 6,
#  ('language', 'default'): 3,
#  ('default', 'region'): 3,
#  ('region', 'store'): 1,
#  ('store', 'display'): 2,
#  ('display', 'properly'): 3,
#  ('properly', 'open'): 1,
#  ('open', 'store'): 2,
#  ('store', 'menu'): 1,
#  ('menu', 'look'): 1,
#  ('look', 'store'): 1,
#  ('store', 'list'): 1,
#  ('list', 'notice'): 2,
#  ('notice', 'default'): 2,
#  ('region', 'display'): 1,
#  ('display', 'correctly'): 1,
#  ('correctly', 'show'): 1,
#  ('show', 'id'): 1,
#  ('id', 'instead'): 1,
#  ('instead', 'correct'): 1,
#  ('correct', 'label'): 2,
#  ('label', 'example'): 1,
#  ('example', 'correct'): 1,
#  ('label', 'default'): 1,
#  ('language', 'english'): 4,
#  ('english', 'us'): 2,
#  ('us', 'show'): 1,
#  ('show', 'en'): 1,
#  ('en', 'us'): 6,
#  ('us', 'instead'): 1,
#  ('instead', 'portal'): 1,
#  ('ap', 'default', 'language'): 1,
#  ('default', 'language', 'default'): 3,
#  ('language', 'default', 'region'): 3,
#  ('default', 'region', 'store'): 1,
#  ('region', 'store', 'display'): 1,
#  ('store', 'display', 'properly'): 1,
#  ('display', 'properly', 'open'): 1,
#  ('properly', 'open', 'store'): 1,
#  ('open', 'store', 'menu'): 1,
#  ('store', 'menu', 'look'): 1,
#  ('menu', 'look', 'store'): 1,
#  ('look', 'store', 'list'): 1,
#  ('store', 'list', 'notice'): 1,
#  ('list', 'notice', 'default'): 1,
#  ('notice', 'default', 'language'): 1,
#  ('default', 'region', 'display'): 1,
#  ('region', 'display', 'correctly'): 1,
#  ('display', 'correctly', 'show'): 1,
#  ('correctly', 'show', 'id'): 1,
#  ('show', 'id', 'instead'): 1,
#  ('id', 'instead', 'correct'): 1,
#  ('instead', 'correct', 'label'): 1,
#  ('correct', 'label', 'example'): 1,
#  ('label', 'example', 'correct'): 1,
#  ('example', 'correct', 'label'): 1,
#  ('correct', 'label', 'default'): 1,
#  ('label', 'default', 'language'): 1,
#  ('default', 'language', 'english'): 1,
#  ('language', 'english', 'us'): 2,
#  ('english', 'us', 'show'): 1,
#  ('us', 'show', 'en'): 1,
#  ('show', 'en', 'us'): 1,
#  ('en', 'us', 'instead'): 1,
#  ('us', 'instead', 'portal'): 1,
#  ('ap', 'default', 'language', 'default'): 1,
#  ('default', 'language', 'default', 'region'): 3,
#  ('language', 'default', 'region', 'store'): 1,
#  ('default', 'region', 'store', 'display'): 1,
#  ('region', 'store', 'display', 'properly'): 1,
#  ('store', 'display', 'properly', 'open'): 1,
#  ('display', 'properly', 'open', 'store'): 1,
#  ('properly', 'open', 'store', 'menu'): 1,
#  ('open', 'store', 'menu', 'look'): 1,
#  ('store', 'menu', 'look', 'store'): 1,
#  ('menu', 'look', 'store', 'list'): 1,
#  ('look', 'store', 'list', 'notice'): 1,
#  ('store', 'list', 'notice', 'default'): 1,
#  ('list', 'notice', 'default', 'language'): 1,
#  ('notice', 'default', 'language', 'default'): 1,
#  ('language', 'default', 'region', 'display'): 1,
#  ('default', 'region', 'display', 'correctly'): 1,
#  ('region', 'display', 'correctly', 'show'): 1,
#  ('display', 'correctly', 'show', 'id'): 1,
#  ('correctly', 'show', 'id', 'instead'): 1,
#  ('show', 'id', 'instead', 'correct'): 1,
#  ('id', 'instead', 'correct', 'label'): 1,
#  ('instead', 'correct', 'label', 'example'): 1,
#  ('correct', 'label', 'example', 'correct'): 1,
#  ('label', 'example', 'correct', 'label'): 1,
#  ('example', 'correct', 'label', 'default'): 1,
#  ('correct', 'label', 'default', 'language'): 1,
#  ('label', 'default', 'language', 'english'): 1,
#  ('default', 'language', 'english', 'us'): 1,
#  ('language', 'english', 'us', 'show'): 1,
#  ('english', 'us', 'show', 'en'): 1,
#  ('us', 'show', 'en', 'us'): 1,
#  ('show', 'en', 'us', 'instead'): 1,
#  ('en', 'us', 'instead', 'portal'): 1,
#  ('unity',): 37,
#  ('sdk',): 141,
#  ('single',): 11,
#  ('restriction',): 2,
#  ('rely',): 6,
#  ('platform',): 54,
#  ('obsolete',): 2,
#  ('feature',): 22,
#  ('multiple',): 12,
#  ('need',): 95,
#  ('rewrite',): 3,
#  ('unity', 'sdk'): 30,
#  ('sdk', 'single'): 2,
#  ('single', 'draft'): 7,
#  ('store', 'make'): 4,
#  ('make', 'subscription'): 4,
#  ('subscription', 'test'): 4,
#  ('test', 'fail'): 8,
#  ('fail', 'restriction'): 2,
#  ('restriction', 'single'): 2,
#  ('test', 'rely'): 2,
#  ('rely', 'platform'): 2,
#  ('platform', 'obsolete'): 2,
#  ('obsolete', 'feature'): 2,
#  ('feature', 'multiple'): 2,
#  ('multiple', 'draft'): 2,
#  ('store', 'fail'): 3,
#  ('fail', 'demo'): 2,
#  ('demo', 'test'): 3,
#  ('test', 'need'): 2,
#  ('need', 'rewrite'): 2,
#  ('rewrite', 'use'): 2,
#  ('use', 'single'): 2,
#  ('store', 'sdk'): 1,
#  ('unity', 'sdk', 'single'): 1,
#  ('sdk', 'single', 'draft'): 2,
#  ('single', 'draft', 'store'): 6,
#  ('draft', 'store', 'make'): 4,
#  ('store', 'make', 'subscription'): 4,
#  ('make', 'subscription', 'test'): 4,
#  ('subscription', 'test', 'fail'): 2,
#  ('test', 'fail', 'restriction'): 2,
#  ('fail', 'restriction', 'single'): 2,
#  ('restriction', 'single', 'draft'): 2,
#  ('subscription', 'test', 'rely'): 2,
#  ('test', 'rely', 'platform'): 2,
#  ('rely', 'platform', 'obsolete'): 2,
#  ('platform', 'obsolete', 'feature'): 2,
#  ('obsolete', 'feature', 'multiple'): 2,
#  ('feature', 'multiple', 'draft'): 2,
#  ('multiple', 'draft', 'store'): 2,
#  ('draft', 'store', 'fail'): 2,
#  ('store', 'fail', 'demo'): 2,
#  ('fail', 'demo', 'test'): 2,
#  ('demo', 'test', 'need'): 2,
#  ('test', 'need', 'rewrite'): 2,
#  ('need', 'rewrite', 'use'): 2,
#  ('rewrite', 'use', 'single'): 2,
#  ('use', 'single', 'draft'): 2,
#  ('draft', 'store', 'sdk'): 1,
#  ('unity', 'sdk', 'single', 'draft'): 1,
#  ('sdk', 'single', 'draft', 'store'): 2,
#  ('single', 'draft', 'store', 'make'): 4,
#  ('draft', 'store', 'make', 'subscription'): 4,
#  ('store', 'make', 'subscription', 'test'): 4,
#  ('make', 'subscription', 'test', 'fail'): 2,
#  ('subscription', 'test', 'fail', 'restriction'): 2,
#  ('test', 'fail', 'restriction', 'single'): 2,
#  ('fail', 'restriction', 'single', 'draft'): 2,
#  ('restriction', 'single', 'draft', 'store'): 2,
#  ('make', 'subscription', 'test', 'rely'): 2,
#  ('subscription', 'test', 'rely', 'platform'): 2,
#  ('test', 'rely', 'platform', 'obsolete'): 2,
#  ('rely', 'platform', 'obsolete', 'feature'): 2,
#  ('platform', 'obsolete', 'feature', 'multiple'): 2,
#  ('obsolete', 'feature', 'multiple', 'draft'): 2,
#  ('feature', 'multiple', 'draft', 'store'): 2,
#  ('multiple', 'draft', 'store', 'fail'): 2,
#  ('draft', 'store', 'fail', 'demo'): 2,
#  ('store', 'fail', 'demo', 'test'): 2,
#  ('fail', 'demo', 'test', 'need'): 2,
#  ('demo', 'test', 'need', 'rewrite'): 2,
#  ('test', 'need', 'rewrite', 'use'): 2,
#  ('need', 'rewrite', 'use', 'single'): 2,
#  ('rewrite', 'use', 'single', 'draft'): 2,
#  ('use', 'single', 'draft', 'store'): 2,
#  ('single', 'draft', 'store', 'sdk'): 1,
#  ('unreal',): 2,
#  ('additional',): 4,
#  ('info',): 17,
#  ('https',): 523,
#  ('sdkbuild',): 9,
#  ('accelbyte',): 558,
#  ('net',): 185,
#  ('job',): 21,
#  ('justice',): 208,
#  ('continuous',): 1,
#  ('integration',): 14,
#  ('artifact',): 9,
#  ('save',): 32,
#  ('log',): 106,
#  ('essentials',): 1,
#  ('unreal', 'sdk'): 2,
#  ('store', 'additional'): 1,
#  ('additional', 'info'): 1,
#  ('info', 'https'): 1,
#  ('https', 'sdkbuild'): 9,
#  ('sdkbuild', 'accelbyte'): 9,
#  ('accelbyte', 'net'): 50,
#  ('net', 'job'): 9,
#  ('job', 'justice'): 9,
#  ('justice', 'unreal'): 1,
#  ('sdk', 'job'): 9,
#  ('job', 'continuous'): 1,
#  ('continuous', 'integration'): 1,
#  ('integration', 'artifact'): 1,
#  ('artifact', 'save'): 9,
#  ('save', 'log'): 9,
#  ('log', 'essentials'): 1,
#  ('essentials', 'log'): 1,
#  ('log', 'log'): 3,
#  ('log', 'sdk'): 3,
#  ('unreal', 'sdk', 'single'): 1,
#  ('draft', 'store', 'additional'): 1,
#  ('store', 'additional', 'info'): 1,
#  ('additional', 'info', 'https'): 1,
#  ('info', 'https', 'sdkbuild'): 1,
#  ('https', 'sdkbuild', 'accelbyte'): 9,
#  ('sdkbuild', 'accelbyte', 'net'): 9,
#  ('accelbyte', 'net', 'job'): 9,
#  ('net', 'job', 'justice'): 9,
#  ('job', 'justice', 'unreal'): 1,
#  ('justice', 'unreal', 'sdk'): 1,
#  ('unreal', 'sdk', 'job'): 1,
#  ('sdk', 'job', 'continuous'): 1,
#  ('job', 'continuous', 'integration'): 1,
#  ('continuous', 'integration', 'artifact'): 1,
#  ('integration', 'artifact', 'save'): 1,
#  ('artifact', 'save', 'log'): 9,
#  ('save', 'log', 'essentials'): 1,
#  ('log', 'essentials', 'log'): 1,
#  ('essentials', 'log', 'log'): 1,
#  ('log', 'log', 'sdk'): 1,
#  ('unreal', 'sdk', 'single', 'draft'): 1,
#  ('single', 'draft', 'store', 'additional'): 1,
#  ('draft', 'store', 'additional', 'info'): 1,
#  ('store', 'additional', 'info', 'https'): 1,
#  ('additional', 'info', 'https', 'sdkbuild'): 1,
#  ('info', 'https', 'sdkbuild', 'accelbyte'): 1,
#  ('https', 'sdkbuild', 'accelbyte', 'net'): 9,
#  ('sdkbuild', 'accelbyte', 'net', 'job'): 9,
#  ('accelbyte', 'net', 'job', 'justice'): 9,
#  ('net', 'job', 'justice', 'unreal'): 1,
#  ('job', 'justice', 'unreal', 'sdk'): 1,
#  ('justice', 'unreal', 'sdk', 'job'): 1,
#  ('unreal', 'sdk', 'job', 'continuous'): 1,
#  ('sdk', 'job', 'continuous', 'integration'): 1,
#  ('job', 'continuous', 'integration', 'artifact'): 1,
#  ('continuous', 'integration', 'artifact', 'save'): 1,
#  ('integration', 'artifact', 'save', 'log'): 1,
#  ('artifact', 'save', 'log', 'essentials'): 1,
#  ('save', 'log', 'essentials', 'log'): 1,
#  ('log', 'essentials', 'log', 'log'): 1,
#  ('essentials', 'log', 'log', 'sdk'): 1,
#  ('feedback',): 24,
#  ('pp',): 158,
#  ('currently',): 14,
#  ('hard',): 7,
#  ('specific',): 21,
#  ('game',): 285,
#  ('want',): 41,
#  ('work',): 29,
#  ('amount',): 34,
#  ('much',): 3,
#  ('pass',): 6,
#  ('certain',): 10,
#  ('become',): 12,
#  ('must',): 11,
#  ('player',): 215,
#  ('feedback', 'pp'): 1,
#  ('pp', 'add'): 3,
#  ('add', 'search'): 1,
#  ('search', 'feature'): 4,
#  ('feature', 'store'): 2,
#  ('store', 'currently'): 2,
#  ('currently', 'search'): 1,
#  ('store', 'pp'): 2,
#  ('pp', 'make'): 2,
#  ('make', 'hard'): 1,
#  ('hard', 'find'): 1,
#  ('find', 'specific'): 1,
#  ('specific', 'game'): 5,
#  ('game', 'want'): 1,
#  ('want', 'page'): 1,
#  ('page', 'work'): 2,
#  ('work', 'amount'): 1,
#  ('amount', 'game'): 1,
#  ('game', 'much'): 1,
#  ('much', 'pass'): 1,
#  ('pass', 'certain'): 1,
#  ('certain', 'amount'): 1,
#  ('amount', 'search'): 1,
#  ('feature', 'become'): 1,
#  ('become', 'must'): 1,
#  ('must', 'player'): 1,
#  ('player', 'portal'): 127,
#  ('feedback', 'pp', 'add'): 1,
#  ('pp', 'add', 'search'): 1,
#  ('add', 'search', 'feature'): 1,
#  ('search', 'feature', 'store'): 2,
#  ('feature', 'store', 'currently'): 1,
#  ('store', 'currently', 'search'): 1,
#  ('currently', 'search', 'feature'): 1,
#  ('feature', 'store', 'pp'): 1,
#  ('store', 'pp', 'make'): 1,
#  ('pp', 'make', 'hard'): 1,
#  ('make', 'hard', 'find'): 1,
#  ('hard', 'find', 'specific'): 1,
#  ('find', 'specific', 'game'): 1,
#  ('specific', 'game', 'want'): 1,
#  ('game', 'want', 'page'): 1,
#  ('want', 'page', 'work'): 1,
#  ('page', 'work', 'amount'): 1,
#  ('work', 'amount', 'game'): 1,
#  ('amount', 'game', 'much'): 1,
#  ('game', 'much', 'pass'): 1,
#  ('much', 'pass', 'certain'): 1,
#  ('pass', 'certain', 'amount'): 1,
#  ('certain', 'amount', 'search'): 1,
#  ('amount', 'search', 'feature'): 1,
#  ('search', 'feature', 'become'): 1,
#  ('feature', 'become', 'must'): 1,
#  ('become', 'must', 'player'): 1,
#  ('must', 'player', 'portal'): 1,
#  ('feedback', 'pp', 'add', 'search'): 1,
#  ('pp', 'add', 'search', 'feature'): 1,
#  ('add', 'search', 'feature', 'store'): 1,
#  ('search', 'feature', 'store', 'currently'): 1,
#  ('feature', 'store', 'currently', 'search'): 1,
#  ('store', 'currently', 'search', 'feature'): 1,
#  ('currently', 'search', 'feature', 'store'): 1,
#  ('search', 'feature', 'store', 'pp'): 1,
#  ('feature', 'store', 'pp', 'make'): 1,
#  ('store', 'pp', 'make', 'hard'): 1,
#  ('pp', 'make', 'hard', 'find'): 1,
#  ('make', 'hard', 'find', 'specific'): 1,
#  ('hard', 'find', 'specific', 'game'): 1,
#  ('find', 'specific', 'game', 'want'): 1,
#  ('specific', 'game', 'want', 'page'): 1,
#  ('game', 'want', 'page', 'work'): 1,
#  ('want', 'page', 'work', 'amount'): 1,
#  ('page', 'work', 'amount', 'game'): 1,
#  ('work', 'amount', 'game', 'much'): 1,
#  ('amount', 'game', 'much', 'pass'): 1,
#  ('game', 'much', 'pass', 'certain'): 1,
#  ('much', 'pass', 'certain', 'amount'): 1,
#  ('pass', 'certain', 'amount', 'search'): 1,
#  ('certain', 'amount', 'search', 'feature'): 1,
#  ('amount', 'search', 'feature', 'become'): 1,
#  ('search', 'feature', 'become', 'must'): 1,
#  ('feature', 'become', 'must', 'player'): 1,
#  ('become', 'must', 'player', 'portal'): 1,
#  ('launcher',): 405,
#  ('avatar',): 8,
#  ('get',): 228,
#  ('customize',): 2,
#  ('photo',): 2,
#  ('happen',): 105,
#  ('choose',): 29,
#  ('continue',): 8,
#  ('demo', 'launcher'): 30,
#  ('launcher', 'avatar'): 1,
#  ('avatar', 'get'): 1,
#  ('get', 'error'): 44,
#  ('error', 'customize'): 1,
#  ('customize', 'avatar'): 2,
#  ('avatar', 'without'): 1,
#  ('without', 'photo'): 2,
#  ('photo', 'issue'): 1,
#  ('issue', 'happen'): 50,
#  ('happen', 'customize'): 1,
#  ('avatar', 'launcher'): 2,
#  ('launcher', 'choose'): 2,
#  ('choose', 'continue'): 1,
#  ('continue', 'without'): 1,
#  ('photo', 'note'): 1,
#  ('note', 'issue'): 15,
#  ('happen', 'player'): 4,
#  ('portal', 'launcher'): 21,
#  ('demo', 'launcher', 'avatar'): 1,
#  ('launcher', 'avatar', 'get'): 1,
#  ('avatar', 'get', 'error'): 1,
#  ('get', 'error', 'customize'): 1,
#  ('error', 'customize', 'avatar'): 1,
#  ('customize', 'avatar', 'without'): 1,
#  ('avatar', 'without', 'photo'): 1,
#  ('without', 'photo', 'issue'): 1,
#  ('photo', 'issue', 'happen'): 1,
#  ('issue', 'happen', 'customize'): 1,
#  ('happen', 'customize', 'avatar'): 1,
#  ('customize', 'avatar', 'launcher'): 1,
#  ('avatar', 'launcher', 'choose'): 1,
#  ('launcher', 'choose', 'continue'): 1,
#  ('choose', 'continue', 'without'): 1,
#  ('continue', 'without', 'photo'): 1,
#  ('without', 'photo', 'note'): 1,
#  ('photo', 'note', 'issue'): 1,
#  ('note', 'issue', 'happen'): 3,
#  ('issue', 'happen', 'player'): 1,
#  ('happen', 'player', 'portal'): 4,
#  ('player', 'portal', 'launcher'): 19,
#  ('demo', 'launcher', 'avatar', 'get'): 1,
#  ('launcher', 'avatar', 'get', 'error'): 1,
#  ('avatar', 'get', 'error', 'customize'): 1,
#  ('get', 'error', 'customize', 'avatar'): 1,
#  ('error', 'customize', 'avatar', 'without'): 1,
#  ('customize', 'avatar', 'without', 'photo'): 1,
#  ('avatar', 'without', 'photo', 'issue'): 1,
#  ('without', 'photo', 'issue', 'happen'): 1,
#  ('photo', 'issue', 'happen', 'customize'): 1,
#  ('issue', 'happen', 'customize', 'avatar'): 1,
#  ('happen', 'customize', 'avatar', 'launcher'): 1,
#  ('customize', 'avatar', 'launcher', 'choose'): 1,
#  ('avatar', 'launcher', 'choose', 'continue'): 1,
#  ('launcher', 'choose', 'continue', 'without'): 1,
#  ('choose', 'continue', 'without', 'photo'): 1,
#  ('continue', 'without', 'photo', 'note'): 1,
#  ('without', 'photo', 'note', 'issue'): 1,
#  ('photo', 'note', 'issue', 'happen'): 1,
#  ('note', 'issue', 'happen', 'player'): 1,
#  ('issue', 'happen', 'player', 'portal'): 1,
#  ('happen', 'player', 'portal', 'launcher'): 2,
#  ('backend',): 133,
#  ('namespace',): 257,
#  ('assign',): 8,
#  ('function',): 67,
#  ('head',): 3,
#  ('click',): 194,
#  ('roles',): 15,
#  ('png',): 58,
#  ('width',): 94,
#  ('height',): 93,
#  ('clone', 'portal'): 1,
#  ('portal', 'backend'): 1,
#  ('backend', 'game'): 1,
#  ('game', 'namespace'): 60,
#  ('namespace', 'assign'): 1,
#  ('assign', 'role'): 4,
#  ('role', 'function'): 1,
#  ('function', 'fail'): 1,
#  ('fail', 'occur'): 1,
#  ('occur', 'head'): 1,
#  ('head', 'game'): 1,
#  ('namespace', 'click'): 3,
#  ('click', 'roles'): 1,
#  ('roles', 'menu'): 1,
#  ('menu', 'try'): 1,
#  ('try', 'assign'): 1,
#  ('role', 'game'): 1,
#  ('namespace', 'fail'): 1,
#  ('fail', 'png'): 1,
#  ('png', 'width'): 42,
#  ('width', 'height'): 93,
#  ('height', 'png'): 2,
#  ('height', 'portal'): 28,
#  ('clone', 'portal', 'backend'): 1,
#  ('portal', 'backend', 'game'): 1,
#  ('backend', 'game', 'namespace'): 1,
#  ('game', 'namespace', 'assign'): 1,
#  ('namespace', 'assign', 'role'): 1,
#  ('assign', 'role', 'function'): 1,
#  ('role', 'function', 'fail'): 1,
#  ('function', 'fail', 'occur'): 1,
#  ('fail', 'occur', 'head'): 1,
#  ('occur', 'head', 'game'): 1,
#  ('head', 'game', 'namespace'): 1,
#  ('game', 'namespace', 'click'): 2,
#  ('namespace', 'click', 'roles'): 1,
#  ('click', 'roles', 'menu'): 1,
#  ('roles', 'menu', 'try'): 1,
#  ('menu', 'try', 'assign'): 1,
#  ('try', 'assign', 'role'): 1,
#  ('assign', 'role', 'game'): 1,
#  ('role', 'game', 'namespace'): 1,
#  ('game', 'namespace', 'fail'): 1,
#  ('namespace', 'fail', 'png'): 1,
#  ('fail', 'png', 'width'): 1,
#  ('png', 'width', 'height'): 42,
#  ('width', 'height', 'png'): 2,
#  ('height', 'png', 'width'): 2,
#  ('width', 'height', 'portal'): 28,
#  ('clone', 'portal', 'backend', 'game'): 1,
#  ('portal', 'backend', 'game', 'namespace'): 1,
#  ('backend', 'game', 'namespace', 'assign'): 1,
#  ('game', 'namespace', 'assign', 'role'): 1,
#  ('namespace', 'assign', 'role', 'function'): 1,
#  ('assign', 'role', 'function', 'fail'): 1,
#  ('role', 'function', 'fail', 'occur'): 1,
#  ('function', 'fail', 'occur', 'head'): 1,
#  ('fail', 'occur', 'head', 'game'): 1,
#  ('occur', 'head', 'game', 'namespace'): 1,
#  ('head', 'game', 'namespace', 'click'): 1,
#  ('game', 'namespace', 'click', 'roles'): 1,
#  ('namespace', 'click', 'roles', 'menu'): 1,
#  ('click', 'roles', 'menu', 'try'): 1,
#  ('roles', 'menu', 'try', 'assign'): 1,
#  ('menu', 'try', 'assign', 'role'): 1,
#  ('try', 'assign', 'role', 'game'): 1,
#  ('assign', 'role', 'game', 'namespace'): 1,
#  ('role', 'game', 'namespace', 'fail'): 1,
#  ('game', 'namespace', 'fail', 'png'): 1,
#  ('namespace', 'fail', 'png', 'width'): 1,
#  ('fail', 'png', 'width', 'height'): 1,
#  ('png', 'width', 'height', 'png'): 2,
#  ('width', 'height', 'png', 'width'): 2,
#  ('height', 'png', 'width', 'height'): 2,
#  ('png', 'width', 'height', 'portal'): 12,
#  ('recharge',): 4,
#  ('wallet',): 19,
#  ('coin',): 23,
#  ('count',): 15,
#  ('refresh',): 31,
#  ('successfully',): 23,
#  ('purchase',): 89,
#  ('succeed',): 1,
#  ('either',): 2,
#  ('go',): 455,
#  ('profile',): 32,
#  ('change',): 154,
#  ('demo', 'pp'): 26,
#  ('pp', 'launcher'): 48,
#  ('launcher', 'recharge'): 2,
#  ('recharge', 'wallet'): 1,
#  ('wallet', 'coin'): 1,
#  ('coin', 'count'): 2,
#  ('count', 'refresh'): 2,
#  ('refresh', 'successfully'): 1,
#  ('successfully', 'purchase'): 1,
#  ('purchase', 'currently'): 1,
#  ('currently', 'coin'): 1,
#  ('refresh', 'purchase'): 1,
#  ('purchase', 'succeed'): 1,
#  ('succeed', 'player'): 1,
#  ('player', 'either'): 1,
#  ('either', 'refresh'): 1,
#  ('refresh', 'page'): 8,
#  ('page', 'go'): 5,
#  ('go', 'profile'): 6,
#  ('profile', 'see'): 1,
#  ('see', 'change'): 1,
#  ('change', 'coin'): 1,
#  ('coin', 'launcher'): 1,
#  ('demo', 'pp', 'launcher'): 13,
#  ('pp', 'launcher', 'recharge'): 1,
#  ('launcher', 'recharge', 'wallet'): 1,
#  ('recharge', 'wallet', 'coin'): 1,
#  ('wallet', 'coin', 'count'): 1,
#  ('coin', 'count', 'refresh'): 2,
#  ('count', 'refresh', 'successfully'): 1,
#  ('refresh', 'successfully', 'purchase'): 1,
#  ('successfully', 'purchase', 'currently'): 1,
#  ('purchase', 'currently', 'coin'): 1,
#  ('currently', 'coin', 'count'): 1,
#  ('count', 'refresh', 'purchase'): 1,
#  ('refresh', 'purchase', 'succeed'): 1,
#  ('purchase', 'succeed', 'player'): 1,
#  ('succeed', 'player', 'either'): 1,
#  ...}

# %%
with open('./Output/MyDFDict.csv', 'w') as f:
    for key in DF.keys():
        f.write("%s,%s\n"%(key,DF[key]))

# %%
n_document = len(listOfSummary)

def calc_IDF(__n_document, __DF):
    IDF_Dict = {}
    for term in __DF:
        IDF_Dict[term] = np.log(__n_document / (__DF[term] + 1))
    return IDF_Dict
  
#Stores the idf dictionary
IDF = calc_IDF(n_document, DF)

# %%
with open('./Output/MyIDFDict.csv', 'w') as f:
    for key in IDF.keys():
        f.write("%s,%s\n"%(key,IDF[key]))

# %%
def compute_jaccard(str1, str2):
    himpunan1 = set(str1)
    himpunan2 = set(str2)
    irisan = himpunan1.intersection(himpunan2)
    IDF_VAL = 0.0
    for key in irisan:
        IDF_VAL = IDF_VAL + IDF[key]
    IDF_VAL = IDF_VAL/(len(irisan)+1)
    gabungan = himpunan1.union(himpunan2)
#     jaccard = IDF_VAL
    jaccard = (len(irisan)/float(len(gabungan))) * IDF_VAL
    
    return jaccard

# %%
import itertools

sim_df = pd.DataFrame()

for col_pair in itertools.combinations_with_replacement(listOfSummary,2):
    strOfCol = str(col_pair)
    
    u0 = col_pair[0]
    u1 = col_pair[1]
    sim_df.loc[str(col_pair[0]), str(col_pair[1])] = compute_jaccard(u0, u1)

# %%
sim_df = sim_df.fillna(0)

# %%
dist = np.array(sim_df)

print(dist)
# Out:
# [[4.62492739e+00 1.75581829e-01 9.12215604e-03 ... 1.17582822e-02
#   1.99635077e-02 1.26680177e-02]
#  [0.00000000e+00 4.58750415e+00 1.70016534e-02 ... 1.53485974e-02
#   2.00699838e-02 1.60069185e-03]
#  [0.00000000e+00 0.00000000e+00 5.21220954e+00 ... 5.17708695e-03
#   1.00865989e-02 1.52505119e-02]
#  ...
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 4.72906094e+00
#   4.12967288e-01 5.98398208e-02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   4.84156430e+00 5.33110308e-02]
#  [0.00000000e+00 0.00000000e+00 0.00000000e+00 ... 0.00000000e+00
#   0.00000000e+00 5.11733156e+00]]

# %%
sim_df.to_csv("./Output/jcidf_matrix.csv")

# %% [markdown]
# ## Agglomerative Hierarchical Clustering

# %%
linkage_matrix = weighted(dist) # replace with complete, single, or other scipy.cluster.hierarchical algorithms

# %% [markdown]
# ## Visualization
#
# Dendrogram visualization. We visualize the titles of each paper next to the corresponding leaf to qualitatively evaluate the clustering.
#
# Changing the `color_threshold` kwarg in the call to `dendrogram()` will affect how the clusters are displayed by increasing or decreasing the
# minimum distance necessary for `dendrogram()` to color a cluster differently.

# %%
# sys.setrecursionlimit(10000)
# MAX_COPHENETIC_DIST = max(linkage_matrix[:,2]) * 0.39 # max distance between points to be considered together. can be tuned.
# MAX_TITLE_LEN = 200

# fig, ax = plt.subplots(figsize=(15, 80)) # set size
# ax = dendrogram(linkage_matrix, orientation="right", color_threshold=MAX_COPHENETIC_DIST, leaf_font_size=4,
#                 labels=Summary.apply(lambda x: x if len(x) < MAX_TITLE_LEN else x[:MAX_TITLE_LEN  - 3] + "...").tolist())

# plt.tick_params(axis= 'x', which='both',  bottom='off', top='off',labelbottom='off')

# plt.tight_layout() #show plot with tight layout
# plt.savefig('./Output/jaccard-idf-coeff-ward.png', dpi=300)

# %% [markdown]
# # Analysis
#
# We now take the raw clusters achieved and use the silhouette score and elbow method to evaluate.

# %%
def silhouette_k(distance_matrix, linkage_matrix, max_k=20):
    scores = []
    for i in range(2, max_k+1):
        clusters = fcluster(linkage_matrix, i, criterion='maxclust')
        score = silhouette_score(distance_matrix, clusters, metric='precomputed')
        print("Silhouette score with {} clusters:".format(i), score)
        scores.append(score)
    plt.title("Silhouette score vs. number of clusters")
    plt.xlabel("# of clusters")
    plt.ylabel("Score (higher is better)")
    plt.plot(np.arange(2, max_k+1), scores)
    plt.show()
    return scores

# %%
np.fill_diagonal(dist, 0)
_ = silhouette_k(dist, linkage_matrix)
# Out:
# Silhouette score with 2 clusters: -0.6938099400712842
# Silhouette score with 3 clusters: -0.9894263041043952
# Silhouette score with 4 clusters: -0.9885227746730257
# Silhouette score with 5 clusters: -0.9876969573501129
# Silhouette score with 6 clusters: -0.987763484828536
# Silhouette score with 7 clusters: -0.9863419975808334
# Silhouette score with 8 clusters: -0.9874173254695656
# Silhouette score with 9 clusters: -0.9859346528696525
# Silhouette score with 10 clusters: -0.9843963600589121
# Silhouette score with 11 clusters: -0.9828580595792801
# Silhouette score with 12 clusters: -0.981319569142859
# Silhouette score with 13 clusters: -0.9799713924564833
# Silhouette score with 14 clusters: -0.9784328753386098
# Silhouette score with 15 clusters: -0.9768944154233372
# Silhouette score with 16 clusters: -0.9753559581407616
# Silhouette score with 17 clusters: -0.9738176214639893
# Silhouette score with 18 clusters: -0.9722791599255277
# Silhouette score with 19 clusters: -0.9707407354868264
# Silhouette score with 20 clusters: -0.9692022739483649
